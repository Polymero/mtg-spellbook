# %%
import requests, json, io
from PIL import Image

# %%
#wop = json.load(open('/home/nika/Downloads/default-cards-20240718211147.json', 'rb'))
wop = json.load(open('C:/Users/Nika/Downloads/default-cards-20240715090650.json', 'rb'))
print(len(wop), 'entries')
print('{:.1f} mb'.format(sum([len(json.dumps(i)) for i in wop]) / 1000 / 1000))
# Out:
# 96589 entries
# '471.2 mb'

# %%
def Flagger(jsonEntries):
    jsonFlagged = []
    skipped = {
        'digitalOnly' : 0,
        'badLayout' : 0,
        'badPromotype' : 0
    }
    for jsonEntry in jsonEntries:
        if 'paper' not in jsonEntry['games']:
            skipped['digitalOnly'] += 1
            continue
        if jsonEntry['layout'] in ['art_series', 'double_faced_token', 'token', 'planar', 'scheme', 'host', 'vanguard', 'emblem']:
            skipped['badLayout'] += 1
            continue
        if 'promo_types' in jsonEntry:
            if 'thick' in jsonEntry['promo_types']:
                skipped['badPromotype'] += 1
                continue
        jsonFlagged.append(jsonEntry)
    return jsonFlagged

flagged = Flagger(wop)
print(len(flagged), 'entries')
print('{:.1f} mb'.format(sum([len(json.dumps(i)) for i in flagged]) / 1000 / 1000))
# Out:
# 83276 entries
# 391.2 mb

# %%
class Face:
    def __init__(self, card):
        self.Name = card['name']
        self.ManaCost = card['mana_cost']
        self.TypeLine = card['type_line']
        self.OracleText = card['oracle_text']
        if 'power' in card: self.Power = card['power']
        else: self.Power = None
        if 'toughness' in card: self.Toughness = card['toughness']
        else: self.Toughness = None
        if 'defense' in card: self.Defense = card['defense']
        else: self.Defense = None
            
    
class Variant:
    FlavorText = None
    FlavorName = None
    def __init__(self, card):
        self.SetName = card['set_name']
        self.SetCode = card['set']
        self.CollNum = card['collector_number']
        self.Finishes = card['finishes']
        self.Artist = card['artist']
        self.Released = card['released_at']
        self.Rarity = card['rarity']
        if 'image_uris' in card:
            self.Thumb = [card['image_uris']['small']]
            self.Image = [card['image_uris']['normal']]
            if 'flavor_text' in card: self.FlavorText = card['flavor_text']
            if 'flavor_name' in card: self.FlavorName = card['flavor_name']
        else:
            self.Thumb = [i['image_uris']['small'] for i in card['card_faces']]
            self.Image = [i['image_uris']['normal'] for i in card['card_faces']]
            if any('flavor_text' in i for i in card['card_faces']):
                self.FlavorText = [i['flavor_text'] if 'flavor_text' in i else '' for i in card['card_faces']]
                self.FlavorName = [i['flavor_name'] if 'flavor_name' in i else '' for i in card['card_faces']]


class OracleCard:
    def __init__(self, card):
        if 'oracle_id' in card: self.OracleId = card['oracle_id']
        else: self.OracleId = card['card_faces'][0]['oracle_id']
        self.Name = card['name']
        if 'card_faces' in card: self.Faces = [Face(i) for i in card['card_faces']]
        else: self.Faces = [Face(card)]
        self.ColorIdentity = card['color_identity']
        if 'cmc' in card: self.CMC = card['cmc']
        else: self.CMC = card['card_faces'][0]['cmc']
        self.Variants = [Variant(card)]
        self.Keywords = card['keywords']
        if 'type_line' in card: self.TypeLine = card['type_line']
        else: self.TypeLine = card['card_faces'][0]['type_line']
        self.Legalities = card['legalities']
    def __repr__(self):
        return json.dumps({
            'Name' : self.Name,
            'Faces' : [i.__dict__ for i in self.Faces],
            'ColorIdentity' : self.ColorIdentity,
            'CMC' : self.CMC,
            'Variants' : [i.__dict__ for i in self.Variants],
            'Keywords' : self.Keywords,
            'TypeLine' : self.TypeLine,
            'Legalities' : self.Legalities
        })

        
database = {}
for i in flagged:
    if 'oracle_id' in i: _oracleId = i['oracle_id']
    else: _oracleId = i['card_faces'][0]['oracle_id']
    if _oracleId in database:
        database[_oracleId].Variants.append(Variant(i))
    else:
        database[_oracleId] = OracleCard(i)
        
print(len(database), 'entries')
print('{:.1f} mb'.format(sum([len(str(database[i])) for i in database]) / 1000 / 1000))
# Out:
# 28622 entries
# 53.1 mb

# %%
[database[i] for i in database if database[i].Faces[0].Defense != None]
# Out:
# [{"Name": "Invasion of Tolvada // The Broken Sky", "Faces": [{"Name": "Invasion of Tolvada", "ManaCost": "{3}{W}{B}", "TypeLine": "Battle \u2014 Siege", "OracleText": "(As a Siege enters, choose an opponent to protect it. You and others can attack it. When it's defeated, exile it, then cast it transformed.)\nWhen Invasion of Tolvada enters the battlefield, return target nonbattle permanent card from your graveyard to the battlefield.", "Power": null, "Toughness": null, "Defense": "5"}, {"Name": "The Broken Sky", "ManaCost": "", "TypeLine": "Enchantment", "OracleText": "Creature tokens you control get +1/+0 and have lifelink.\nAt the beginning of your end step, create a 1/1 white and black Spirit creature token with flying.", "Power": null, "Toughness": null, "Defense": null}], "ColorIdentity": ["B", "W"], "CMC": 5.0, "Variants": [{"SetName": "March of the Machine", "SetCode": "mom", "CollNum": "241", "Finishes": ["nonfoil", "foil"], "Artist": "Henry Peters", "Language": "en", "Released": "2023-04-21", "Rarity": "rare", "Thumb": ["https://cards.scryfall.io/small/front/0/0/00255899-aaaf-46c6-8037-bd0e3c06250c.jpg?1682715701", "https://cards.scryfall.io/small/back/0/0/00255899-aaaf-46c6-8037-bd0e3c06250c.jpg?1682715701"], "Image": ["https://cards.scryfall.io/normal/front/0/0/00255899-aaaf-46c6-8037-bd0e3c06250c.jpg?1682715701", "https://cards.scryfall.io/normal/back/0/0/00255899-aaaf-46c6-8037-bd0e3c06250c.jpg?1682715701"], "FlavorText": ["", "Angry ghosts poured through and pummeled the Invasion Tree, filling the heavens with the rhythms of war."], "FlavorName": ["", ""]}, {"SetName": "March of the Machine Promos", "SetCode": "pmom", "CollNum": "241s", "Finishes": ["foil"], "Artist": "Henry Peters", "Language": "en", "Released": "2023-04-21", "Rarity": "rare", "Thumb": ["https://cards.scryfall.io/small/front/b/b/bb7bbe0f-3b19-42a4-981c-97164711f63c.jpg?1682717374", "https://cards.scryfall.io/small/back/b/b/bb7bbe0f-3b19-42a4-981c-97164711f63c.jpg?1682717374"], "Image": ["https://cards.scryfall.io/normal/front/b/b/bb7bbe0f-3b19-42a4-981c-97164711f63c.jpg?1682717374", "https://cards.scryfall.io/normal/back/b/b/bb7bbe0f-3b19-42a4-981c-97164711f63c.jpg?1682717374"], "FlavorText": ["", "Angry ghosts poured through and pummeled the Invasion Tree, filling the heavens with the rhythms of war."], "FlavorName": ["", ""]}], "Keywords": ["Transform"], "TypeLine": "Battle \u2014 Siege // Enchantment", "Legalities": {"standard": "legal", "future": "legal", "historic": "legal", "timeless": "legal", "gladiator": "legal", "pioneer": "legal", "explorer": "legal", "modern": "legal", "legacy": "legal", "pauper": "not_legal", "vintage": "legal", "penny": "legal", "commander": "legal", "oathbreaker": "legal", "standardbrawl": "legal", "brawl": "legal", "alchemy": "legal", "paupercommander": "not_legal", "duel": "legal", "oldschool": "not_legal", "premodern": "not_legal", "predh": "not_legal"}},
#  {"Name": "Invasion of Fiora // Marchesa, Resolute Monarch", "Faces": [{"Name": "Invasion of Fiora", "ManaCost": "{4}{B}{B}", "TypeLine": "Battle \u2014 Siege", "OracleText": "(As a Siege enters, choose an opponent to protect it. You and others can attack it. When it's defeated, exile it, then cast it transformed.)\nWhen Invasion of Fiora enters the battlefield, choose one or both \u2014\n\u2022 Destroy all legendary creatures.\n\u2022 Destroy all nonlegendary creatures.", "Power": null, "Toughness": null, "Defense": "4"}, {"Name": "Marchesa, Resolute Monarch", "ManaCost": "", "TypeLine": "Legendary Creature \u2014 Human Noble", "OracleText": "Menace, deathtouch\nWhenever Marchesa, Resolute Monarch attacks, remove all counters from up to one target permanent.\nAt the beginning of your upkeep, if you haven't been dealt combat damage since your last turn, you draw a card and you lose 1 life.", "Power": "3", "Toughness": "6", "Defense": null}], "ColorIdentity": ["B"], "CMC": 6.0, "Variants": [{"SetName": "March of the Machine Promos", "SetCode": "pmom", "CollNum": "114s", "Finishes": ["foil"], "Artist": "Joshua Raphael", "Language": "en", "Released": "2023-04-21", "Rarity": "rare", "Thumb": ["https://cards.scryfall.io/small/front/0/5/05a292df-4323-4789-bba4-7f4599e24027.jpg?1682717206", "https://cards.scryfall.io/small/back/0/5/05a292df-4323-4789-bba4-7f4599e24027.jpg?1682717206"], "Image": ["https://cards.scryfall.io/normal/front/0/5/05a292df-4323-4789-bba4-7f4599e24027.jpg?1682717206", "https://cards.scryfall.io/normal/back/0/5/05a292df-4323-4789-bba4-7f4599e24027.jpg?1682717206"]}, {"SetName": "March of the Machine", "SetCode": "mom", "CollNum": "114", "Finishes": ["nonfoil", "foil"], "Artist": "Joshua Raphael", "Language": "en", "Released": "2023-04-21", "Rarity": "rare", "Thumb": ["https://cards.scryfall.io/small/front/b/3/b3af679b-6ee6-4a1d-8ec3-b659bdd90b4a.jpg?1682715245", "https://cards.scryfall.io/small/back/b/3/b3af679b-6ee6-4a1d-8ec3-b659bdd90b4a.jpg?1682715245"], "Image": ["https://cards.scryfall.io/normal/front/b/3/b3af679b-6ee6-4a1d-8ec3-b659bdd90b4a.jpg?1682715245", "https://cards.scryfall.io/normal/back/b/3/b3af679b-6ee6-4a1d-8ec3-b659bdd90b4a.jpg?1682715245"]}], "Keywords": ["Transform", "Menace", "Deathtouch"], "TypeLine": "Battle \u2014 Siege // Legendary Creature \u2014 Human Noble", "Legalities": {"standard": "legal", "future": "legal", "historic": "legal", "timeless": "legal", "gladiator": "legal", "pioneer": "legal", "explorer": "legal", "modern": "legal", "legacy": "legal", "pauper": "not_legal", "vintage": "legal", "penny": "legal", "commander": "legal", "oathbreaker": "legal", "standardbrawl": "legal", "brawl": "legal", "alchemy": "legal", "paupercommander": "not_legal", "duel": "legal", "oldschool": "not_legal", "premodern": "not_legal", "predh": "not_legal"}},
#  {"Name": "Invasion of Gobakhan // Lightshield Array", "Faces": [{"Name": "Invasion of Gobakhan", "ManaCost": "{1}{W}", "TypeLine": "Battle \u2014 Siege", "OracleText": "(As a Siege enters, choose an opponent to protect it. You and others can attack it. When it's defeated, exile it, then cast it transformed.)\nWhen Invasion of Gobakhan enters the battlefield, look at target opponent's hand. You may exile a nonland card from it. For as long as that card remains exiled, its owner may play it. A spell cast this way costs {2} more to cast.", "Power": null, "Toughness": null, "Defense": "3"}, {"Name": "Lightshield Array", "ManaCost": "", "TypeLine": "Enchantment", "OracleText": "At the beginning of your end step, put a +1/+1 counter on each creature that attacked this turn.\nSacrifice Lightshield Array: Creatures you control gain hexproof and indestructible until end of turn.", "Power": null, "Toughness": null, "Defense": null}], "ColorIdentity": ["W"], "CMC": 2.0, "Variants": [{"SetName": "March of the Machine", "SetCode": "mom", "CollNum": "22", "Finishes": ["nonfoil", "foil"], "Artist": "Andreas Zafiratos", "Language": "en", "Released": "2023-04-21", "Rarity": "rare", "Thumb": ["https://cards.scryfall.io/small/front/1/1/11798730-6788-4e0b-a828-b46cab1a4fa7.jpg?1682715250", "https://cards.scryfall.io/small/back/1/1/11798730-6788-4e0b-a828-b46cab1a4fa7.jpg?1682715250"], "Image": ["https://cards.scryfall.io/normal/front/1/1/11798730-6788-4e0b-a828-b46cab1a4fa7.jpg?1682715250", "https://cards.scryfall.io/normal/back/1/1/11798730-6788-4e0b-a828-b46cab1a4fa7.jpg?1682715250"], "FlavorText": ["", "The weight of Phyrexia crashed down upon Gobakhan, but the will of its people endured."], "FlavorName": ["", ""]}, {"SetName": "March of the Machine Promos", "SetCode": "pmom", "CollNum": "22s", "Finishes": ["foil"], "Artist": "Andreas Zafiratos", "Language": "en", "Released": "2023-04-21", "Rarity": "rare", "Thumb": ["https://cards.scryfall.io/small/front/a/0/a0baccde-b9ca-42e5-9ed6-29d1acf43d7f.jpg?1682717156", "https://cards.scryfall.io/small/back/a/0/a0baccde-b9ca-42e5-9ed6-29d1acf43d7f.jpg?1682717156"], "Image": ["https://cards.scryfall.io/normal/front/a/0/a0baccde-b9ca-42e5-9ed6-29d1acf43d7f.jpg?1682717156", "https://cards.scryfall.io/normal/back/a/0/a0baccde-b9ca-42e5-9ed6-29d1acf43d7f.jpg?1682717156"], "FlavorText": ["", "The weight of Phyrexia crashed down upon Gobakhan, but the will of its people endured."], "FlavorName": ["", ""]}], "Keywords": ["Transform"], "TypeLine": "Battle \u2014 Siege // Enchantment", "Legalities": {"standard": "legal", "future": "legal", "historic": "legal", "timeless": "legal", "gladiator": "legal", "pioneer": "legal", "explorer": "legal", "modern": "legal", "legacy": "legal", "pauper": "not_legal", "vintage": "legal", "penny": "not_legal", "commander": "legal", "oathbreaker": "legal", "standardbrawl": "legal", "brawl": "legal", "alchemy": "legal", "paupercommander": "not_legal", "duel": "legal", "oldschool": "not_legal", "premodern": "not_legal", "predh": "not_legal"}},
#  {"Name": "Invasion of Innistrad // Deluge of the Dead", "Faces": [{"Name": "Invasion of Innistrad", "ManaCost": "{2}{B}{B}", "TypeLine": "Battle \u2014 Siege", "OracleText": "(As a Siege enters, choose an opponent to protect it. You and others can attack it. When it's defeated, exile it, then cast it transformed.)\nFlash\nWhen Invasion of Innistrad enters the battlefield, target creature an opponent controls gets -13/-13 until end of turn.", "Power": null, "Toughness": null, "Defense": "5"}, {"Name": "Deluge of the Dead", "ManaCost": "", "TypeLine": "Enchantment", "OracleText": "When Deluge of the Dead enters the battlefield, create two 2/2 black Zombie creature tokens.\n{2}{B}: Exile target card from a graveyard. If it was a creature card, create a 2/2 black Zombie creature token.", "Power": null, "Toughness": null, "Defense": null}], "ColorIdentity": ["B"], "CMC": 4.0, "Variants": [{"SetName": "March of the Machine Promos", "SetCode": "pmom", "CollNum": "115s", "Finishes": ["foil"], "Artist": "Alexey Kruglov", "Language": "en", "Released": "2023-04-21", "Rarity": "mythic", "Thumb": ["https://cards.scryfall.io/small/front/1/4/144c4e3b-1679-4937-8637-05a98295168a.jpg?1682717213", "https://cards.scryfall.io/small/back/1/4/144c4e3b-1679-4937-8637-05a98295168a.jpg?1682717213"], "Image": ["https://cards.scryfall.io/normal/front/1/4/144c4e3b-1679-4937-8637-05a98295168a.jpg?1682717213", "https://cards.scryfall.io/normal/back/1/4/144c4e3b-1679-4937-8637-05a98295168a.jpg?1682717213"], "FlavorText": ["", "The eerie magic animating Innistrad's zombies rendered them immune to phyresis, making them crucial to the plane's defense."], "FlavorName": ["", ""]}, {"SetName": "March of the Machine", "SetCode": "mom", "CollNum": "115", "Finishes": ["nonfoil", "foil"], "Artist": "Alexey Kruglov", "Language": "en", "Released": "2023-04-21", "Rarity": "mythic", "Thumb": ["https://cards.scryfall.io/small/front/7/7/77720d2e-2b7b-492b-852c-eea5061eb31b.jpg?1682715272", "https://cards.scryfall.io/small/back/7/7/77720d2e-2b7b-492b-852c-eea5061eb31b.jpg?1682715272"], "Image": ["https://cards.scryfall.io/normal/front/7/7/77720d2e-2b7b-492b-852c-eea5061eb31b.jpg?1682715272", "https://cards.scryfall.io/normal/back/7/7/77720d2e-2b7b-492b-852c-eea5061eb31b.jpg?1682715272"], "FlavorText": ["", "The eerie magic animating Innistrad's zombies rendered them immune to phyresis, making them crucial to the plane's defense."], "FlavorName": ["", ""]}], "Keywords": ["Transform", "Flash"], "TypeLine": "Battle \u2014 Siege // Enchantment", "Legalities": {"standard": "legal", "future": "legal", "historic": "legal", "timeless": "legal", "gladiator": "legal", "pioneer": "legal", "explorer": "legal", "modern": "legal", "legacy": "legal", "pauper": "not_legal", "vintage": "legal", "penny": "not_legal", "commander": "legal", "oathbreaker": "legal", "standardbrawl": "legal", "brawl": "legal", "alchemy": "legal", "paupercommander": "not_legal", "duel": "legal", "oldschool": "not_legal", "premodern": "not_legal", "predh": "not_legal"}},
#  {"Name": "Invasion of New Phyrexia // Teferi Akosa of Zhalfir", "Faces": [{"Name": "Invasion of New Phyrexia", "ManaCost": "{X}{W}{U}", "TypeLine": "Battle \u2014 Siege", "OracleText": "(As a Siege enters, choose an opponent to protect it. You and others can attack it. When it's defeated, exile it, then cast it transformed.)\nWhen Invasion of New Phyrexia enters the battlefield, create X 2/2 white and blue Knight creature tokens with vigilance.", "Power": null, "Toughness": null, "Defense": "6"}, {"Name": "Teferi Akosa of Zhalfir", "ManaCost": "", "TypeLine": "Legendary Planeswalker \u2014 Teferi", "OracleText": "+1: Draw two cards. Then discard two cards unless you discard a creature card.\n\u22122: You get an emblem with \"Knights you control get +1/+0 and have ward {1}.\"\n\u22123: Tap any number of untapped creatures you control. When you do, shuffle target nonland permanent an opponent controls with mana value X or less into its owner's library, where X is the number of creatures tapped this way.", "Power": null, "Toughness": null, "Defense": null}], "ColorIdentity": ["U", "W"], "CMC": 2.0, "Variants": [{"SetName": "March of the Machine", "SetCode": "mom", "CollNum": "239", "Finishes": ["nonfoil", "foil"], "Artist": "Chris Rallis", "Language": "en", "Released": "2023-04-21", "Rarity": "mythic", "Thumb": ["https://cards.scryfall.io/small/front/1/b/1b83af86-e1a9-4be1-83dc-0c1ab81b129e.jpg?1692183624", "https://cards.scryfall.io/small/back/1/b/1b83af86-e1a9-4be1-83dc-0c1ab81b129e.jpg?1692183624"], "Image": ["https://cards.scryfall.io/normal/front/1/b/1b83af86-e1a9-4be1-83dc-0c1ab81b129e.jpg?1692183624", "https://cards.scryfall.io/normal/back/1/b/1b83af86-e1a9-4be1-83dc-0c1ab81b129e.jpg?1692183624"]}, {"SetName": "March of the Machine Promos", "SetCode": "pmom", "CollNum": "239s", "Finishes": ["foil"], "Artist": "Chris Rallis", "Language": "en", "Released": "2023-04-21", "Rarity": "mythic", "Thumb": ["https://cards.scryfall.io/small/front/c/c/cc0c163b-1fce-422d-bd70-ee8aa7f250f2.jpg?1682717361", "https://cards.scryfall.io/small/back/c/c/cc0c163b-1fce-422d-bd70-ee8aa7f250f2.jpg?1682717361"], "Image": ["https://cards.scryfall.io/normal/front/c/c/cc0c163b-1fce-422d-bd70-ee8aa7f250f2.jpg?1682717361", "https://cards.scryfall.io/normal/back/c/c/cc0c163b-1fce-422d-bd70-ee8aa7f250f2.jpg?1682717361"]}], "Keywords": ["Transform"], "TypeLine": "Battle \u2014 Siege // Legendary Planeswalker \u2014 Teferi", "Legalities": {"standard": "legal", "future": "legal", "historic": "legal", "timeless": "legal", "gladiator": "legal", "pioneer": "legal", "explorer": "legal", "modern": "legal", "legacy": "legal", "pauper": "not_legal", "vintage": "legal", "penny": "not_legal", "commander": "legal", "oathbreaker": "legal", "standardbrawl": "legal", "brawl": "legal", "alchemy": "legal", "paupercommander": "not_legal", "duel": "legal", "oldschool": "not_legal", "premodern": "not_legal", "predh": "not_legal"}},
#  {"Name": "Invasion of Arcavios // Invocation of the Founders", "Faces": [{"Name": "Invasion of Arcavios", "ManaCost": "{3}{U}{U}", "TypeLine": "Battle \u2014 Siege", "OracleText": "(As a Siege enters, choose an opponent to protect it. You and others can attack it. When it's defeated, exile it, then cast it transformed.)\nWhen Invasion of Arcavios enters the battlefield, search your library, graveyard, and/or outside the game for an instant or sorcery card you own, reveal it, and put it into your hand. If you search your library this way, shuffle.", "Power": null, "Toughness": null, "Defense": "7"}, {"Name": "Invocation of the Founders", "ManaCost": "", "TypeLine": "Enchantment", "OracleText": "Whenever you cast an instant or sorcery spell from your hand, you may copy that spell. You may choose new targets for the copy.", "Power": null, "Toughness": null, "Defense": null}], "ColorIdentity": ["U"], "CMC": 5.0, "Variants": [{"SetName": "March of the Machine", "SetCode": "mom", "CollNum": "61", "Finishes": ["nonfoil", "foil"], "Artist": "Dmitry Burmak", "Language": "en", "Released": "2023-04-21", "Rarity": "rare", "Thumb": ["https://cards.scryfall.io/small/front/1/c/1c3f661d-b9f7-48e7-afe3-3eaea1022bc1.jpg?1682715201", "https://cards.scryfall.io/small/back/1/c/1c3f661d-b9f7-48e7-afe3-3eaea1022bc1.jpg?1682715201"], "Image": ["https://cards.scryfall.io/normal/front/1/c/1c3f661d-b9f7-48e7-afe3-3eaea1022bc1.jpg?1682715201", "https://cards.scryfall.io/normal/back/1/c/1c3f661d-b9f7-48e7-afe3-3eaea1022bc1.jpg?1682715201"], "FlavorText": ["", "No professors, no grades, no room for mistakes."], "FlavorName": ["", ""]}, {"SetName": "March of the Machine Promos", "SetCode": "pmom", "CollNum": "61s", "Finishes": ["foil"], "Artist": "Dmitry Burmak", "Language": "en", "Released": "2023-04-21", "Rarity": "rare", "Thumb": ["https://cards.scryfall.io/small/front/9/4/94598f7c-5142-49f2-b3b8-137b246492b9.jpg?1682717170", "https://cards.scryfall.io/small/back/9/4/94598f7c-5142-49f2-b3b8-137b246492b9.jpg?1682717170"], "Image": ["https://cards.scryfall.io/normal/front/9/4/94598f7c-5142-49f2-b3b8-137b246492b9.jpg?1682717170", "https://cards.scryfall.io/normal/back/9/4/94598f7c-5142-49f2-b3b8-137b246492b9.jpg?1682717170"], "FlavorText": ["", "No professors, no grades, no room for mistakes."], "FlavorName": ["", ""]}], "Keywords": ["Transform"], "TypeLine": "Battle \u2014 Siege // Enchantment", "Legalities": {"standard": "legal", "future": "legal", "historic": "legal", "timeless": "legal", "gladiator": "legal", "pioneer": "legal", "explorer": "legal", "modern": "legal", "legacy": "legal", "pauper": "not_legal", "vintage": "legal", "penny": "legal", "commander": "legal", "oathbreaker": "legal", "standardbrawl": "legal", "brawl": "legal", "alchemy": "legal", "paupercommander": "not_legal", "duel": "legal", "oldschool": "not_legal", "premodern": "not_legal", "predh": "not_legal"}},
#  {"Name": "Invasion of Kamigawa // Rooftop Saboteurs", "Faces": [{"Name": "Invasion of Kamigawa", "ManaCost": "{3}{U}", "TypeLine": "Battle \u2014 Siege", "OracleText": "(As a Siege enters, choose an opponent to protect it. You and others can attack it. When it's defeated, exile it, then cast it transformed.)\nWhen Invasion of Kamigawa enters the battlefield, tap target artifact or creature an opponent controls and put a stun counter on it. (If a permanent with a stun counter would become untapped, remove one from it instead.)", "Power": null, "Toughness": null, "Defense": "4"}, {"Name": "Rooftop Saboteurs", "ManaCost": "", "TypeLine": "Creature \u2014 Moonfolk Ninja", "OracleText": "Flying\nWhenever Rooftop Saboteurs deals combat damage to a player or battle, draw a card.", "Power": "2", "Toughness": "3", "Defense": null}], "ColorIdentity": ["U"], "CMC": 4.0, "Variants": [{"SetName": "March of the Machine", "SetCode": "mom", "CollNum": "62", "Finishes": ["nonfoil", "foil"], "Artist": "Kekai Kotaki", "Language": "en", "Released": "2023-04-21", "Rarity": "uncommon", "Thumb": ["https://cards.scryfall.io/small/front/3/1/3140320d-b932-441f-bff3-9bdf4419b88a.jpg?1682715337", "https://cards.scryfall.io/small/back/3/1/3140320d-b932-441f-bff3-9bdf4419b88a.jpg?1682715337"], "Image": ["https://cards.scryfall.io/normal/front/3/1/3140320d-b932-441f-bff3-9bdf4419b88a.jpg?1682715337", "https://cards.scryfall.io/normal/back/3/1/3140320d-b932-441f-bff3-9bdf4419b88a.jpg?1682715337"], "FlavorText": ["", "The pace of Kamigawa's development meant that Jin-Gitaxias's intel was already outdated when the invaders arrived."], "FlavorName": ["", ""]}], "Keywords": ["Flying", "Transform"], "TypeLine": "Battle \u2014 Siege // Creature \u2014 Moonfolk Ninja", "Legalities": {"standard": "legal", "future": "legal", "historic": "legal", "timeless": "legal", "gladiator": "legal", "pioneer": "legal", "explorer": "legal", "modern": "legal", "legacy": "legal", "pauper": "not_legal", "vintage": "legal", "penny": "not_legal", "commander": "legal", "oathbreaker": "legal", "standardbrawl": "legal", "brawl": "legal", "alchemy": "legal", "paupercommander": "not_legal", "duel": "legal", "oldschool": "not_legal", "premodern": "not_legal", "predh": "not_legal"}},
#  {"Name": "Invasion of Alara // Awaken the Maelstrom", "Faces": [{"Name": "Invasion of Alara", "ManaCost": "{W}{U}{B}{R}{G}", "TypeLine": "Battle \u2014 Siege", "OracleText": "When Invasion of Alara enters the battlefield, exile cards from the top of your library until you exile two nonland cards with mana value 4 or less. You may cast one of those two cards without paying its mana cost. Put one of them into your hand. Then put the other cards exiled this way on the bottom of your library in a random order.", "Power": null, "Toughness": null, "Defense": "7"}, {"Name": "Awaken the Maelstrom", "ManaCost": "", "TypeLine": "Sorcery", "OracleText": "Awaken the Maelstrom is all colors.\nTarget player draws two cards. You may put an artifact card from your hand onto the battlefield. Create a token that's a copy of a permanent you control. Distribute three +1/+1 counters among one, two, or three creatures you control. Destroy target permanent an opponent controls.", "Power": null, "Toughness": null, "Defense": null}], "ColorIdentity": ["B", "G", "R", "U", "W"], "CMC": 5.0, "Variants": [{"SetName": "March of the Machine", "SetCode": "mom", "CollNum": "230", "Finishes": ["nonfoil", "foil"], "Artist": "Mathias Kollros", "Language": "en", "Released": "2023-04-21", "Rarity": "rare", "Thumb": ["https://cards.scryfall.io/small/front/3/1/318c363b-61cc-4e2f-8f86-a4287539ea07.jpg?1682715186", "https://cards.scryfall.io/small/back/3/1/318c363b-61cc-4e2f-8f86-a4287539ea07.jpg?1682715186"], "Image": ["https://cards.scryfall.io/normal/front/3/1/318c363b-61cc-4e2f-8f86-a4287539ea07.jpg?1682715186", "https://cards.scryfall.io/normal/back/3/1/318c363b-61cc-4e2f-8f86-a4287539ea07.jpg?1682715186"]}, {"SetName": "March of the Machine Promos", "SetCode": "pmom", "CollNum": "230s", "Finishes": ["foil"], "Artist": "Mathias Kollros", "Language": "en", "Released": "2023-04-21", "Rarity": "rare", "Thumb": ["https://cards.scryfall.io/small/front/4/b/4b717f04-4162-4d80-a739-5d848481d2bf.jpg?1682717298", "https://cards.scryfall.io/small/back/4/b/4b717f04-4162-4d80-a739-5d848481d2bf.jpg?1682717298"], "Image": ["https://cards.scryfall.io/normal/front/4/b/4b717f04-4162-4d80-a739-5d848481d2bf.jpg?1682717298", "https://cards.scryfall.io/normal/back/4/b/4b717f04-4162-4d80-a739-5d848481d2bf.jpg?1682717298"]}], "Keywords": [], "TypeLine": "Battle \u2014 Siege // Sorcery", "Legalities": {"standard": "legal", "future": "legal", "historic": "legal", "timeless": "legal", "gladiator": "legal", "pioneer": "legal", "explorer": "legal", "modern": "legal", "legacy": "legal", "pauper": "not_legal", "vintage": "legal", "penny": "legal", "commander": "legal", "oathbreaker": "legal", "standardbrawl": "legal", "brawl": "legal", "alchemy": "legal", "paupercommander": "not_legal", "duel": "legal", "oldschool": "not_legal", "premodern": "not_legal", "predh": "not_legal"}},
#  {"Name": "Invasion of Ixalan // Belligerent Regisaur", "Faces": [{"Name": "Invasion of Ixalan", "ManaCost": "{1}{G}", "TypeLine": "Battle \u2014 Siege", "OracleText": "(As a Siege enters, choose an opponent to protect it. You and others can attack it. When it's defeated, exile it, then cast it transformed.)\nWhen Invasion of Ixalan enters the battlefield, look at the top five cards of your library. You may reveal a permanent card from among them and put it into your hand. Put the rest on the bottom of your library in a random order.", "Power": null, "Toughness": null, "Defense": "4"}, {"Name": "Belligerent Regisaur", "ManaCost": "", "TypeLine": "Creature \u2014 Dinosaur", "OracleText": "Trample\nWhenever you cast a spell, Belligerent Regisaur gains indestructible until end of turn.", "Power": "4", "Toughness": "3", "Defense": null}], "ColorIdentity": ["G"], "CMC": 2.0, "Variants": [{"SetName": "March of the Machine Promos", "SetCode": "pmom", "CollNum": "191s", "Finishes": ["foil"], "Artist": "Viktor Titov", "Language": "en", "Released": "2023-04-21", "Rarity": "rare", "Thumb": ["https://cards.scryfall.io/small/front/3/b/3befb543-547a-46ac-8488-a7f2069d3d88.jpg?1682717269", "https://cards.scryfall.io/small/back/3/b/3befb543-547a-46ac-8488-a7f2069d3d88.jpg?1682717269"], "Image": ["https://cards.scryfall.io/normal/front/3/b/3befb543-547a-46ac-8488-a7f2069d3d88.jpg?1682717269", "https://cards.scryfall.io/normal/back/3/b/3befb543-547a-46ac-8488-a7f2069d3d88.jpg?1682717269"], "FlavorText": ["", "\"Careful. Its vision is based on fear, and it can smell movement . . . or something like that.\"\n\u2014Gregor, amateur zoologist"], "FlavorName": ["", ""]}, {"SetName": "March of the Machine", "SetCode": "mom", "CollNum": "191", "Finishes": ["nonfoil", "foil"], "Artist": "Viktor Titov", "Language": "en", "Released": "2023-04-21", "Rarity": "rare", "Thumb": ["https://cards.scryfall.io/small/front/f/a/fa20fc16-e106-4953-ace4-5ac9c7fec97b.jpg?1682715316", "https://cards.scryfall.io/small/back/f/a/fa20fc16-e106-4953-ace4-5ac9c7fec97b.jpg?1682715316"], "Image": ["https://cards.scryfall.io/normal/front/f/a/fa20fc16-e106-4953-ace4-5ac9c7fec97b.jpg?1682715316", "https://cards.scryfall.io/normal/back/f/a/fa20fc16-e106-4953-ace4-5ac9c7fec97b.jpg?1682715316"], "FlavorText": ["", "\"Careful. Its vision is based on fear, and it can smell movement . . . or something like that.\"\n\u2014Gregor, amateur zoologist"], "FlavorName": ["", ""]}], "Keywords": ["Transform", "Trample"], "TypeLine": "Battle \u2014 Siege // Creature \u2014 Dinosaur", "Legalities": {"standard": "legal", "future": "legal", "historic": "legal", "timeless": "legal", "gladiator": "legal", "pioneer": "legal", "explorer": "legal", "modern": "legal", "legacy": "legal", "pauper": "not_legal", "vintage": "legal", "penny": "not_legal", "commander": "legal", "oathbreaker": "legal", "standardbrawl": "legal", "brawl": "legal", "alchemy": "legal", "paupercommander": "not_legal", "duel": "legal", "oldschool": "not_legal", "premodern": "not_legal", "predh": "not_legal"}},
#  {"Name": "Invasion of Mercadia // Kyren Flamewright", "Faces": [{"Name": "Invasion of Mercadia", "ManaCost": "{1}{R}", "TypeLine": "Battle \u2014 Siege", "OracleText": "(As a Siege enters, choose an opponent to protect it. You and others can attack it. When it's defeated, exile it, then cast it transformed.)\nWhen Invasion of Mercadia enters the battlefield, you may discard a card. If you do, draw two cards.", "Power": null, "Toughness": null, "Defense": "4"}, {"Name": "Kyren Flamewright", "ManaCost": "", "TypeLine": "Creature \u2014 Goblin Spellshaper", "OracleText": "{2}{R}, {T}, Discard a card: Create two 1/1 blue and red Elemental creature tokens. Creatures you control get +1/+0 and gain haste until end of turn.", "Power": "3", "Toughness": "3", "Defense": null}], "ColorIdentity": ["R"], "CMC": 2.0, "Variants": [{"SetName": "March of the Machine", "SetCode": "mom", "CollNum": "147", "Finishes": ["nonfoil", "foil"], "Artist": "Cristi Balanescu", "Language": "en", "Released": "2023-04-21", "Rarity": "uncommon", "Thumb": ["https://cards.scryfall.io/small/front/4/0/407d6723-bf58-403e-b2ac-ba52c51d356f.jpg?1682715363", "https://cards.scryfall.io/small/back/4/0/407d6723-bf58-403e-b2ac-ba52c51d356f.jpg?1682715363"], "Image": ["https://cards.scryfall.io/normal/front/4/0/407d6723-bf58-403e-b2ac-ba52c51d356f.jpg?1682715363", "https://cards.scryfall.io/normal/back/4/0/407d6723-bf58-403e-b2ac-ba52c51d356f.jpg?1682715363"], "FlavorText": ["", "Inspired by tales of the legendary hero Squee, many young Kyren goblins strove to emulate his magical skill and courage in the face of danger."], "FlavorName": ["", ""]}], "Keywords": ["Transform"], "TypeLine": "Battle \u2014 Siege // Creature \u2014 Goblin Spellshaper", "Legalities": {"standard": "legal", "future": "legal", "historic": "legal", "timeless": "legal", "gladiator": "legal", "pioneer": "legal", "explorer": "legal", "modern": "legal", "legacy": "legal", "pauper": "not_legal", "vintage": "legal", "penny": "not_legal", "commander": "legal", "oathbreaker": "legal", "standardbrawl": "legal", "brawl": "legal", "alchemy": "legal", "paupercommander": "not_legal", "duel": "legal", "oldschool": "not_legal", "premodern": "not_legal", "predh": "not_legal"}},
#  {"Name": "Invasion of Theros // Ephara, Ever-Sheltering", "Faces": [{"Name": "Invasion of Theros", "ManaCost": "{2}{W}", "TypeLine": "Battle \u2014 Siege", "OracleText": "(As a Siege enters, choose an opponent to protect it. You and others can attack it. When it's defeated, exile it, then cast it transformed.)\nWhen Invasion of Theros enters the battlefield, search your library for an Aura, God, or Demigod card, reveal it, put it into your hand, then shuffle.", "Power": null, "Toughness": null, "Defense": "4"}, {"Name": "Ephara, Ever-Sheltering", "ManaCost": "", "TypeLine": "Legendary Enchantment Creature \u2014 God", "OracleText": "Ephara, Ever-Sheltering has lifelink and indestructible as long as you control at least three other enchantments.\nWhenever another enchantment enters the battlefield under your control, draw a card.", "Power": "4", "Toughness": "4", "Defense": null}], "ColorIdentity": ["U", "W"], "CMC": 3.0, "Variants": [{"SetName": "March of the Machine", "SetCode": "mom", "CollNum": "23", "Finishes": ["nonfoil", "foil"], "Artist": "Johan Grenier", "Language": "en", "Released": "2023-04-21", "Rarity": "rare", "Thumb": ["https://cards.scryfall.io/small/front/4/3/433e9f1c-9d6c-4c7e-89d0-79595b4331f2.jpg?1689854843", "https://cards.scryfall.io/small/back/4/3/433e9f1c-9d6c-4c7e-89d0-79595b4331f2.jpg?1689854843"], "Image": ["https://cards.scryfall.io/normal/front/4/3/433e9f1c-9d6c-4c7e-89d0-79595b4331f2.jpg?1689854843", "https://cards.scryfall.io/normal/back/4/3/433e9f1c-9d6c-4c7e-89d0-79595b4331f2.jpg?1689854843"], "FlavorText": ["", "When the sun falters and the seas disperse, when the wilds wither and the forges go cold, when death itself succumbs, she endures."], "FlavorName": ["", ""]}, {"SetName": "March of the Machine Promos", "SetCode": "pmom", "CollNum": "23s", "Finishes": ["foil"], "Artist": "Johan Grenier", "Language": "en", "Released": "2023-04-21", "Rarity": "rare", "Thumb": ["https://cards.scryfall.io/small/front/b/4/b45a1e7b-716a-4a32-b573-765e4f677476.jpg?1689854852", "https://cards.scryfall.io/small/back/b/4/b45a1e7b-716a-4a32-b573-765e4f677476.jpg?1689854852"], "Image": ["https://cards.scryfall.io/normal/front/b/4/b45a1e7b-716a-4a32-b573-765e4f677476.jpg?1689854852", "https://cards.scryfall.io/normal/back/b/4/b45a1e7b-716a-4a32-b573-765e4f677476.jpg?1689854852"], "FlavorText": ["", "When the sun falters and the seas disperse, when the wilds wither and the forges go cold, when death itself succumbs, she endures."], "FlavorName": ["", ""]}], "Keywords": ["Transform"], "TypeLine": "Battle \u2014 Siege // Legendary Enchantment Creature \u2014 God", "Legalities": {"standard": "legal", "future": "legal", "historic": "legal", "timeless": "legal", "gladiator": "legal", "pioneer": "legal", "explorer": "legal", "modern": "legal", "legacy": "legal", "pauper": "not_legal", "vintage": "legal", "penny": "legal", "commander": "legal", "oathbreaker": "legal", "standardbrawl": "legal", "brawl": "legal", "alchemy": "legal", "paupercommander": "not_legal", "duel": "legal", "oldschool": "not_legal", "premodern": "not_legal", "predh": "not_legal"}},
#  {"Name": "Invasion of Ulgrotha // Grandmother Ravi Sengir", "Faces": [{"Name": "Invasion of Ulgrotha", "ManaCost": "{4}{B}", "TypeLine": "Battle \u2014 Siege", "OracleText": "(As a Siege enters, choose an opponent to protect it. You and others can attack it. When it's defeated, exile it, then cast it transformed.)\nWhen Invasion of Ulgrotha enters the battlefield, it deals 3 damage to any other target and you gain 3 life.", "Power": null, "Toughness": null, "Defense": "5"}, {"Name": "Grandmother Ravi Sengir", "ManaCost": "", "TypeLine": "Legendary Creature \u2014 Human Wizard", "OracleText": "Flying\nWhenever a creature an opponent controls dies, put a +1/+1 counter on Grandmother Ravi Sengir and you gain 1 life.", "Power": "3", "Toughness": "3", "Defense": null}], "ColorIdentity": ["B"], "CMC": 5.0, "Variants": [{"SetName": "March of the Machine", "SetCode": "mom", "CollNum": "116", "Finishes": ["nonfoil", "foil"], "Artist": "Viko Menezes", "Language": "en", "Released": "2023-04-21", "Rarity": "uncommon", "Thumb": ["https://cards.scryfall.io/small/front/4/9/49ec5e00-22f4-486e-8e99-e950725f6fbc.jpg?1682715707", "https://cards.scryfall.io/small/back/4/9/49ec5e00-22f4-486e-8e99-e950725f6fbc.jpg?1682715707"], "Image": ["https://cards.scryfall.io/normal/front/4/9/49ec5e00-22f4-486e-8e99-e950725f6fbc.jpg?1682715707", "https://cards.scryfall.io/normal/back/4/9/49ec5e00-22f4-486e-8e99-e950725f6fbc.jpg?1682715707"], "FlavorText": ["", "\"I do enjoy a good apocalypse.\""], "FlavorName": ["", ""]}], "Keywords": ["Flying", "Transform"], "TypeLine": "Battle \u2014 Siege // Legendary Creature \u2014 Human Wizard", "Legalities": {"standard": "legal", "future": "legal", "historic": "legal", "timeless": "legal", "gladiator": "legal", "pioneer": "legal", "explorer": "legal", "modern": "legal", "legacy": "legal", "pauper": "not_legal", "vintage": "legal", "penny": "not_legal", "commander": "legal", "oathbreaker": "legal", "standardbrawl": "legal", "brawl": "legal", "alchemy": "legal", "paupercommander": "not_legal", "duel": "legal", "oldschool": "not_legal", "premodern": "not_legal", "predh": "not_legal"}},
#  {"Name": "Invasion of Kaladesh // Aetherwing, Golden-Scale Flagship", "Faces": [{"Name": "Invasion of Kaladesh", "ManaCost": "{U}{R}", "TypeLine": "Battle \u2014 Siege", "OracleText": "(As a Siege enters, choose an opponent to protect it. You and others can attack it. When it's defeated, exile it, then cast it transformed.)\nWhen Invasion of Kaladesh enters the battlefield, create a 1/1 colorless Thopter artifact creature token with flying.", "Power": null, "Toughness": null, "Defense": "4"}, {"Name": "Aetherwing, Golden-Scale Flagship", "ManaCost": "", "TypeLine": "Legendary Artifact \u2014 Vehicle", "OracleText": "Flying\nAetherwing, Golden-Scale Flagship's power is equal to the number of artifacts you control.\nCrew 1 (Tap any number of creatures you control with total power 1 or more: This Vehicle becomes an artifact creature until end of turn.)", "Power": "*", "Toughness": "4", "Defense": null}], "ColorIdentity": ["R", "U"], "CMC": 2.0, "Variants": [{"SetName": "March of the Machine", "SetCode": "mom", "CollNum": "234", "Finishes": ["nonfoil", "foil"], "Artist": "Leon Tukker", "Language": "en", "Released": "2023-04-21", "Rarity": "uncommon", "Thumb": ["https://cards.scryfall.io/small/front/4/f/4f7231f6-8adc-4a68-9984-e56b974c087b.jpg?1682715324", "https://cards.scryfall.io/small/back/4/f/4f7231f6-8adc-4a68-9984-e56b974c087b.jpg?1682715324"], "Image": ["https://cards.scryfall.io/normal/front/4/f/4f7231f6-8adc-4a68-9984-e56b974c087b.jpg?1682715324", "https://cards.scryfall.io/normal/back/4/f/4f7231f6-8adc-4a68-9984-e56b974c087b.jpg?1682715324"], "FlavorText": ["", "Inspired by the grace of Ixalan's pterodons, Saheeli built one of her own."], "FlavorName": ["", ""]}], "Keywords": ["Flying", "Transform", "Crew"], "TypeLine": "Battle \u2014 Siege // Legendary Artifact \u2014 Vehicle", "Legalities": {"standard": "legal", "future": "legal", "historic": "legal", "timeless": "legal", "gladiator": "legal", "pioneer": "legal", "explorer": "legal", "modern": "legal", "legacy": "legal", "pauper": "not_legal", "vintage": "legal", "penny": "not_legal", "commander": "legal", "oathbreaker": "legal", "standardbrawl": "legal", "brawl": "legal", "alchemy": "legal", "paupercommander": "not_legal", "duel": "legal", "oldschool": "not_legal", "premodern": "not_legal", "predh": "not_legal"}},
#  {"Name": "Invasion of Belenon // Belenon War Anthem", "Faces": [{"Name": "Invasion of Belenon", "ManaCost": "{2}{W}", "TypeLine": "Battle \u2014 Siege", "OracleText": "(As a Siege enters, choose an opponent to protect it. You and others can attack it. When it's defeated, exile it, then cast it transformed.)\nWhen Invasion of Belenon enters the battlefield, create a 2/2 white and blue Knight creature token with vigilance.", "Power": null, "Toughness": null, "Defense": "5"}, {"Name": "Belenon War Anthem", "ManaCost": "", "TypeLine": "Enchantment", "OracleText": "Creatures you control get +1/+1.", "Power": null, "Toughness": null, "Defense": null}], "ColorIdentity": ["W"], "CMC": 3.0, "Variants": [{"SetName": "March of the Machine", "SetCode": "mom", "CollNum": "20", "Finishes": ["nonfoil", "foil"], "Artist": "Antonio Jos\u00e9 Manzanedo", "Language": "en", "Released": "2023-04-21", "Rarity": "uncommon", "Thumb": ["https://cards.scryfall.io/small/front/4/f/4fb0eb2d-9cb7-4e72-a970-5009b046df2a.jpg?1682796205", "https://cards.scryfall.io/small/back/4/f/4fb0eb2d-9cb7-4e72-a970-5009b046df2a.jpg?1682796205"], "Image": ["https://cards.scryfall.io/normal/front/4/f/4fb0eb2d-9cb7-4e72-a970-5009b046df2a.jpg?1682796205", "https://cards.scryfall.io/normal/back/4/f/4fb0eb2d-9cb7-4e72-a970-5009b046df2a.jpg?1682796205"], "FlavorText": ["", "\"Just as a flute turns breath into music, we are the vessel through which the Sacred Winds produce glorious justice.\""], "FlavorName": ["", ""]}], "Keywords": ["Transform"], "TypeLine": "Battle \u2014 Siege // Enchantment", "Legalities": {"standard": "legal", "future": "legal", "historic": "legal", "timeless": "legal", "gladiator": "legal", "pioneer": "legal", "explorer": "legal", "modern": "legal", "legacy": "legal", "pauper": "not_legal", "vintage": "legal", "penny": "not_legal", "commander": "legal", "oathbreaker": "legal", "standardbrawl": "legal", "brawl": "legal", "alchemy": "legal", "paupercommander": "not_legal", "duel": "legal", "oldschool": "not_legal", "premodern": "not_legal", "predh": "not_legal"}},
#  {"Name": "Invasion of Pyrulea // Gargantuan Slabhorn", "Faces": [{"Name": "Invasion of Pyrulea", "ManaCost": "{G}{U}", "TypeLine": "Battle \u2014 Siege", "OracleText": "(As a Siege enters, choose an opponent to protect it. You and others can attack it. When it's defeated, exile it, then cast it transformed.)\nWhen Invasion of Pyrulea enters the battlefield, scry 3, then reveal the top card of your library. If it's a land or double-faced card, draw a card.", "Power": null, "Toughness": null, "Defense": "4"}, {"Name": "Gargantuan Slabhorn", "ManaCost": "", "TypeLine": "Creature \u2014 Beast", "OracleText": "Trample, ward {2}\nOther transformed permanents you control have trample and ward {2}.", "Power": "4", "Toughness": "4", "Defense": null}], "ColorIdentity": ["G", "U"], "CMC": 2.0, "Variants": [{"SetName": "March of the Machine", "SetCode": "mom", "CollNum": "240", "Finishes": ["nonfoil", "foil"], "Artist": "Nicholas Gregory", "Language": "en", "Released": "2023-04-21", "Rarity": "uncommon", "Thumb": ["https://cards.scryfall.io/small/front/5/0/50180fda-6d67-41e9-8b2b-2e7c5876b8ab.jpg?1682715555", "https://cards.scryfall.io/small/back/5/0/50180fda-6d67-41e9-8b2b-2e7c5876b8ab.jpg?1682715555"], "Image": ["https://cards.scryfall.io/normal/front/5/0/50180fda-6d67-41e9-8b2b-2e7c5876b8ab.jpg?1682715555", "https://cards.scryfall.io/normal/back/5/0/50180fda-6d67-41e9-8b2b-2e7c5876b8ab.jpg?1682715555"], "FlavorText": ["", "To the slabhorn, the branches of the Invasion Tree were as brittle as the stems of a Pyrulean fern."], "FlavorName": ["", ""]}], "Keywords": ["Transform", "Trample", "Ward", "Scry"], "TypeLine": "Battle \u2014 Siege // Creature \u2014 Beast", "Legalities": {"standard": "legal", "future": "legal", "historic": "legal", "timeless": "legal", "gladiator": "legal", "pioneer": "legal", "explorer": "legal", "modern": "legal", "legacy": "legal", "pauper": "not_legal", "vintage": "legal", "penny": "not_legal", "commander": "legal", "oathbreaker": "legal", "standardbrawl": "legal", "brawl": "legal", "alchemy": "legal", "paupercommander": "not_legal", "duel": "legal", "oldschool": "not_legal", "premodern": "not_legal", "predh": "not_legal"}},
#  {"Name": "Invasion of Ravnica // Guildpact Paragon", "Faces": [{"Name": "Invasion of Ravnica", "ManaCost": "{5}", "TypeLine": "Battle \u2014 Siege", "OracleText": "(As a Siege enters, choose an opponent to protect it. You and others can attack it. When it's defeated, exile it, then cast it transformed.)\nWhen Invasion of Ravnica enters the battlefield, exile target nonland permanent an opponent controls that isn't exactly two colors.", "Power": null, "Toughness": null, "Defense": "4"}, {"Name": "Guildpact Paragon", "ManaCost": "", "TypeLine": "Artifact Creature \u2014 Construct", "OracleText": "Whenever you cast a spell that's exactly two colors, look at the top six cards of your library. You may reveal a card that's exactly two colors from among them and put it into your hand. Put the rest on the bottom of your library in a random order.", "Power": "5", "Toughness": "5", "Defense": null}], "ColorIdentity": [], "CMC": 5.0, "Variants": [{"SetName": "March of the Machine Promos", "SetCode": "pmom", "CollNum": "1s", "Finishes": ["foil"], "Artist": "Leon Tukker", "Language": "en", "Released": "2023-04-21", "Rarity": "mythic", "Thumb": ["https://cards.scryfall.io/small/front/5/7/573cc5ec-4892-4f24-ba65-82d51198af89.jpg?1682717133", "https://cards.scryfall.io/small/back/5/7/573cc5ec-4892-4f24-ba65-82d51198af89.jpg?1682717133"], "Image": ["https://cards.scryfall.io/normal/front/5/7/573cc5ec-4892-4f24-ba65-82d51198af89.jpg?1682717133", "https://cards.scryfall.io/normal/back/5/7/573cc5ec-4892-4f24-ba65-82d51198af89.jpg?1682717133"]}, {"SetName": "March of the Machine", "SetCode": "mom", "CollNum": "1", "Finishes": ["nonfoil", "foil"], "Artist": "Leon Tukker", "Language": "en", "Released": "2023-04-21", "Rarity": "mythic", "Thumb": ["https://cards.scryfall.io/small/front/7/3/73f8fc4f-2f36-4932-8d04-3c2651c116dc.jpg?1682704897", "https://cards.scryfall.io/small/back/7/3/73f8fc4f-2f36-4932-8d04-3c2651c116dc.jpg?1682704897"], "Image": ["https://cards.scryfall.io/normal/front/7/3/73f8fc4f-2f36-4932-8d04-3c2651c116dc.jpg?1682704897", "https://cards.scryfall.io/normal/back/7/3/73f8fc4f-2f36-4932-8d04-3c2651c116dc.jpg?1682704897"]}], "Keywords": ["Transform"], "TypeLine": "Battle \u2014 Siege // Artifact Creature \u2014 Construct", "Legalities": {"standard": "legal", "future": "legal", "historic": "legal", "timeless": "legal", "gladiator": "legal", "pioneer": "legal", "explorer": "legal", "modern": "legal", "legacy": "legal", "pauper": "not_legal", "vintage": "legal", "penny": "not_legal", "commander": "legal", "oathbreaker": "legal", "standardbrawl": "legal", "brawl": "legal", "alchemy": "legal", "paupercommander": "not_legal", "duel": "legal", "oldschool": "not_legal", "premodern": "not_legal", "predh": "not_legal"}},
#  {"Name": "Invasion of Ikoria // Zilortha, Apex of Ikoria", "Faces": [{"Name": "Invasion of Ikoria", "ManaCost": "{X}{G}{G}", "TypeLine": "Battle \u2014 Siege", "OracleText": "(As a Siege enters, choose an opponent to protect it. You and others can attack it. When it's defeated, exile it, then cast it transformed.)\nWhen Invasion of Ikoria enters the battlefield, search your library and/or graveyard for a non-Human creature card with mana value X or less and put it onto the battlefield. If you search your library this way, shuffle.", "Power": null, "Toughness": null, "Defense": "6"}, {"Name": "Zilortha, Apex of Ikoria", "ManaCost": "", "TypeLine": "Legendary Creature \u2014 Dinosaur", "OracleText": "Reach\nFor each non-Human creature you control, you may have that creature assign its combat damage as though it weren't blocked.", "Power": "8", "Toughness": "8", "Defense": null}], "ColorIdentity": ["G"], "CMC": 2.0, "Variants": [{"SetName": "March of the Machine", "SetCode": "mom", "CollNum": "190", "Finishes": ["nonfoil", "foil"], "Artist": "Antonio Jos\u00e9 Manzanedo", "Language": "en", "Released": "2023-04-21", "Rarity": "rare", "Thumb": ["https://cards.scryfall.io/small/front/5/d/5d59c8f2-f6af-40a6-8dfe-8cc45bf231ce.jpg?1682715265", "https://cards.scryfall.io/small/back/5/d/5d59c8f2-f6af-40a6-8dfe-8cc45bf231ce.jpg?1682715265"], "Image": ["https://cards.scryfall.io/normal/front/5/d/5d59c8f2-f6af-40a6-8dfe-8cc45bf231ce.jpg?1682715265", "https://cards.scryfall.io/normal/back/5/d/5d59c8f2-f6af-40a6-8dfe-8cc45bf231ce.jpg?1682715265"], "FlavorText": ["", "Phyrexia's largest goliaths stormed Ikoria, ready to challenge the world's great monsters. Zilortha was unimpressed."], "FlavorName": ["", ""]}, {"SetName": "March of the Machine Promos", "SetCode": "pmom", "CollNum": "190s", "Finishes": ["foil"], "Artist": "Antonio Jos\u00e9 Manzanedo", "Language": "en", "Released": "2023-04-21", "Rarity": "rare", "Thumb": ["https://cards.scryfall.io/small/front/e/2/e277f9d2-b809-4edd-aa8f-e28e13a6d349.jpg?1682717262", "https://cards.scryfall.io/small/back/e/2/e277f9d2-b809-4edd-aa8f-e28e13a6d349.jpg?1682717262"], "Image": ["https://cards.scryfall.io/normal/front/e/2/e277f9d2-b809-4edd-aa8f-e28e13a6d349.jpg?1682717262", "https://cards.scryfall.io/normal/back/e/2/e277f9d2-b809-4edd-aa8f-e28e13a6d349.jpg?1682717262"], "FlavorText": ["", "Phyrexia's largest goliaths stormed Ikoria, ready to challenge the world's great monsters. Zilortha was unimpressed."], "FlavorName": ["", ""]}], "Keywords": ["Reach", "Transform"], "TypeLine": "Battle \u2014 Siege // Legendary Creature \u2014 Dinosaur", "Legalities": {"standard": "legal", "future": "legal", "historic": "legal", "timeless": "legal", "gladiator": "legal", "pioneer": "legal", "explorer": "legal", "modern": "legal", "legacy": "legal", "pauper": "not_legal", "vintage": "legal", "penny": "not_legal", "commander": "legal", "oathbreaker": "legal", "standardbrawl": "legal", "brawl": "legal", "alchemy": "legal", "paupercommander": "not_legal", "duel": "legal", "oldschool": "not_legal", "premodern": "not_legal", "predh": "not_legal"}},
# ...
#  {"Name": "Invasion of Azgol // Ashen Reaper", "Faces": [{"Name": "Invasion of Azgol", "ManaCost": "{B}{R}", "TypeLine": "Battle \u2014 Siege", "OracleText": "(As a Siege enters, choose an opponent to protect it. You and others can attack it. When it's defeated, exile it, then cast it transformed.)\nWhen Invasion of Azgol enters the battlefield, target player sacrifices a creature or planeswalker and loses 1 life.", "Power": null, "Toughness": null, "Defense": "4"}, {"Name": "Ashen Reaper", "ManaCost": "", "TypeLine": "Creature \u2014 Zombie Elemental", "OracleText": "Menace\nAt the beginning of your end step, put a +1/+1 counter on Ashen Reaper if a permanent was put into a graveyard from the battlefield this turn.", "Power": "2", "Toughness": "1", "Defense": null}], "ColorIdentity": ["B", "R"], "CMC": 2.0, "Variants": [{"SetName": "March of the Machine", "SetCode": "mom", "CollNum": "232", "Finishes": ["nonfoil", "foil"], "Artist": "Joshua Raphael", "Language": "en", "Released": "2023-04-21", "Rarity": "uncommon", "Thumb": ["https://cards.scryfall.io/small/front/a/e/ae2e1244-f05b-45f9-8afc-59f190524798.jpg?1682715207", "https://cards.scryfall.io/small/back/a/e/ae2e1244-f05b-45f9-8afc-59f190524798.jpg?1682715207"], "Image": ["https://cards.scryfall.io/normal/front/a/e/ae2e1244-f05b-45f9-8afc-59f190524798.jpg?1682715207", "https://cards.scryfall.io/normal/back/a/e/ae2e1244-f05b-45f9-8afc-59f190524798.jpg?1682715207"], "FlavorText": ["", "Eternal hatred fuels eternal fire."], "FlavorName": ["", ""]}], "Keywords": ["Transform", "Menace"], "TypeLine": "Battle \u2014 Siege // Creature \u2014 Zombie Elemental", "Legalities": {"standard": "legal", "future": "legal", "historic": "legal", "timeless": "legal", "gladiator": "legal", "pioneer": "legal", "explorer": "legal", "modern": "legal", "legacy": "legal", "pauper": "not_legal", "vintage": "legal", "penny": "not_legal", "commander": "legal", "oathbreaker": "legal", "standardbrawl": "legal", "brawl": "legal", "alchemy": "legal", "paupercommander": "not_legal", "duel": "legal", "oldschool": "not_legal", "premodern": "not_legal", "predh": "not_legal"}},
#  {"Name": "Invasion of Ergamon // Truga Cliffcharger", "Faces": [{"Name": "Invasion of Ergamon", "ManaCost": "{R}{G}", "TypeLine": "Battle \u2014 Siege", "OracleText": "(As a Siege enters, choose an opponent to protect it. You and others can attack it. When it's defeated, exile it, then cast it transformed.)\nWhen Invasion of Ergamon enters the battlefield, create a Treasure token. Then you may discard a card. If you do, draw a card.", "Power": null, "Toughness": null, "Defense": "5"}, {"Name": "Truga Cliffcharger", "ManaCost": "", "TypeLine": "Creature \u2014 Rhino", "OracleText": "Trample\nWhen Truga Cliffcharger enters the battlefield, you may discard a card. If you do, search your library for a land or battle card, reveal it, put it into your hand, then shuffle.", "Power": "3", "Toughness": "4", "Defense": null}], "ColorIdentity": ["G", "R"], "CMC": 2.0, "Variants": [{"SetName": "March of the Machine", "SetCode": "mom", "CollNum": "233", "Finishes": ["nonfoil", "foil"], "Artist": "Manuel Casta\u00f1\u00f3n", "Language": "en", "Released": "2023-04-21", "Rarity": "uncommon", "Thumb": ["https://cards.scryfall.io/small/front/b/3/b3e0fc49-f765-4bd1-a2b9-23e703388b50.jpg?1682715237", "https://cards.scryfall.io/small/back/b/3/b3e0fc49-f765-4bd1-a2b9-23e703388b50.jpg?1682715237"], "Image": ["https://cards.scryfall.io/normal/front/b/3/b3e0fc49-f765-4bd1-a2b9-23e703388b50.jpg?1682715237", "https://cards.scryfall.io/normal/back/b/3/b3e0fc49-f765-4bd1-a2b9-23e703388b50.jpg?1682715237"], "FlavorText": ["", "Throughout Ergamon's wild Truga Jungle, predator-prey relationships stopped until every last invader was crushed to dust."], "FlavorName": ["", ""]}], "Keywords": ["Transform", "Treasure", "Trample"], "TypeLine": "Battle \u2014 Siege // Creature \u2014 Rhino", "Legalities": {"standard": "legal", "future": "legal", "historic": "legal", "timeless": "legal", "gladiator": "legal", "pioneer": "legal", "explorer": "legal", "modern": "legal", "legacy": "legal", "pauper": "not_legal", "vintage": "legal", "penny": "not_legal", "commander": "legal", "oathbreaker": "legal", "standardbrawl": "legal", "brawl": "legal", "alchemy": "legal", "paupercommander": "not_legal", "duel": "legal", "oldschool": "not_legal", "premodern": "not_legal", "predh": "not_legal"}},
#  {"Name": "Invasion of Kaldheim // Pyre of the World Tree", "Faces": [{"Name": "Invasion of Kaldheim", "ManaCost": "{3}{R}", "TypeLine": "Battle \u2014 Siege", "OracleText": "(As a Siege enters, choose an opponent to protect it. You and others can attack it. When it's defeated, exile it, then cast it transformed.)\nWhen Invasion of Kaldheim enters the battlefield, exile all cards from your hand, then draw that many cards. Until the end of your next turn, you may play cards exiled this way.", "Power": null, "Toughness": null, "Defense": "4"}, {"Name": "Pyre of the World Tree", "ManaCost": "", "TypeLine": "Enchantment", "OracleText": "Discard a land card: Pyre of the World Tree deals 2 damage to any target.\nWhenever you discard a land card, exile the top card of your library. You may play that card this turn.", "Power": null, "Toughness": null, "Defense": null}], "ColorIdentity": ["R"], "CMC": 4.0, "Variants": [{"SetName": "March of the Machine Promos", "SetCode": "pmom", "CollNum": "145s", "Finishes": ["foil"], "Artist": "Bryan Sola", "Language": "en", "Released": "2023-04-21", "Rarity": "rare", "Thumb": ["https://cards.scryfall.io/small/front/b/7/b7848601-5b0d-4c1a-b3b3-79572d7a0a1c.jpg?1682717227", "https://cards.scryfall.io/small/back/b/7/b7848601-5b0d-4c1a-b3b3-79572d7a0a1c.jpg?1682717227"], "Image": ["https://cards.scryfall.io/normal/front/b/7/b7848601-5b0d-4c1a-b3b3-79572d7a0a1c.jpg?1682717227", "https://cards.scryfall.io/normal/back/b/7/b7848601-5b0d-4c1a-b3b3-79572d7a0a1c.jpg?1682717227"], "FlavorText": ["", "The warriors of Kaldheim burned the soul of their world to keep it out of Phyrexia's hands."], "FlavorName": ["", ""]}, {"SetName": "March of the Machine", "SetCode": "mom", "CollNum": "145", "Finishes": ["nonfoil", "foil"], "Artist": "Bryan Sola", "Language": "en", "Released": "2023-04-21", "Rarity": "rare", "Thumb": ["https://cards.scryfall.io/small/front/f/7/f7cedd62-efc8-464d-8387-220bb55e07e9.jpg?1682715332", "https://cards.scryfall.io/small/back/f/7/f7cedd62-efc8-464d-8387-220bb55e07e9.jpg?1682715332"], "Image": ["https://cards.scryfall.io/normal/front/f/7/f7cedd62-efc8-464d-8387-220bb55e07e9.jpg?1682715332", "https://cards.scryfall.io/normal/back/f/7/f7cedd62-efc8-464d-8387-220bb55e07e9.jpg?1682715332"], "FlavorText": ["", "The warriors of Kaldheim burned the soul of their world to keep it out of Phyrexia's hands."], "FlavorName": ["", ""]}], "Keywords": ["Transform"], "TypeLine": "Battle \u2014 Siege // Enchantment", "Legalities": {"standard": "legal", "future": "legal", "historic": "legal", "timeless": "legal", "gladiator": "legal", "pioneer": "legal", "explorer": "legal", "modern": "legal", "legacy": "legal", "pauper": "not_legal", "vintage": "legal", "penny": "legal", "commander": "legal", "oathbreaker": "legal", "standardbrawl": "legal", "brawl": "legal", "alchemy": "legal", "paupercommander": "not_legal", "duel": "legal", "oldschool": "not_legal", "premodern": "not_legal", "predh": "not_legal"}},
#  {"Name": "Invasion of Vryn // Overloaded Mage-Ring", "Faces": [{"Name": "Invasion of Vryn", "ManaCost": "{3}{U}", "TypeLine": "Battle \u2014 Siege", "OracleText": "(As a Siege enters, choose an opponent to protect it. You and others can attack it. When it's defeated, exile it, then cast it transformed.)\nWhen Invasion of Vryn enters the battlefield, draw three cards, then discard a card.", "Power": null, "Toughness": null, "Defense": "4"}, {"Name": "Overloaded Mage-Ring", "ManaCost": "", "TypeLine": "Artifact", "OracleText": "{1}, {T}, Sacrifice Overloaded Mage-Ring: Copy target spell you control. You may choose new targets for the copy. (A copy of a permanent spell becomes a token.)", "Power": null, "Toughness": null, "Defense": null}], "ColorIdentity": ["U"], "CMC": 4.0, "Variants": [{"SetName": "March of the Machine", "SetCode": "mom", "CollNum": "64", "Finishes": ["nonfoil", "foil"], "Artist": "Leon Tukker", "Language": "en", "Released": "2023-04-21", "Rarity": "uncommon", "Thumb": ["https://cards.scryfall.io/small/front/c/0/c0ef6737-8e85-42ca-8ee6-6a34f9462de3.jpg?1684933911", "https://cards.scryfall.io/small/back/c/0/c0ef6737-8e85-42ca-8ee6-6a34f9462de3.jpg?1684933911"], "Image": ["https://cards.scryfall.io/normal/front/c/0/c0ef6737-8e85-42ca-8ee6-6a34f9462de3.jpg?1684933911", "https://cards.scryfall.io/normal/back/c/0/c0ef6737-8e85-42ca-8ee6-6a34f9462de3.jpg?1684933911"], "FlavorText": ["", "\"On my signal, disable the safeguards. Let's blow these metal freaks right back to their own world!\"\n\u2014Gav Beleren, mage-ring engineer"], "FlavorName": ["", ""]}], "Keywords": ["Transform"], "TypeLine": "Battle \u2014 Siege // Artifact", "Legalities": {"standard": "legal", "future": "legal", "historic": "legal", "timeless": "legal", "gladiator": "legal", "pioneer": "legal", "explorer": "legal", "modern": "legal", "legacy": "legal", "pauper": "not_legal", "vintage": "legal", "penny": "not_legal", "commander": "legal", "oathbreaker": "legal", "standardbrawl": "legal", "brawl": "legal", "alchemy": "legal", "paupercommander": "not_legal", "duel": "legal", "oldschool": "not_legal", "premodern": "not_legal", "predh": "not_legal"}},
#  {"Name": "Invasion of Moag // Bloomwielder Dryads", "Faces": [{"Name": "Invasion of Moag", "ManaCost": "{2}{G}{W}", "TypeLine": "Battle \u2014 Siege", "OracleText": "(As a Siege enters, choose an opponent to protect it. You and others can attack it. When it's defeated, exile it, then cast it transformed.)\nWhen Invasion of Moag enters the battlefield, put a +1/+1 counter on each creature you control.", "Power": null, "Toughness": null, "Defense": "5"}, {"Name": "Bloomwielder Dryads", "ManaCost": "", "TypeLine": "Creature \u2014 Dryad", "OracleText": "Ward {2} (Whenever this creature becomes the target of a spell or ability an opponent controls, counter it unless that player pays {2}.)\nAt the beginning of your end step, put a +1/+1 counter on target creature you control.", "Power": "3", "Toughness": "3", "Defense": null}], "ColorIdentity": ["G", "W"], "CMC": 4.0, "Variants": [{"SetName": "March of the Machine", "SetCode": "mom", "CollNum": "237", "Finishes": ["nonfoil", "foil"], "Artist": "Filip Burburan", "Language": "en", "Released": "2023-04-21", "Rarity": "uncommon", "Thumb": ["https://cards.scryfall.io/small/front/e/4/e454bf31-5aa0-4109-a3f5-c3f9cc838682.jpg?1682715370", "https://cards.scryfall.io/small/back/e/4/e454bf31-5aa0-4109-a3f5-c3f9cc838682.jpg?1682715370"], "Image": ["https://cards.scryfall.io/normal/front/e/4/e454bf31-5aa0-4109-a3f5-c3f9cc838682.jpg?1682715370", "https://cards.scryfall.io/normal/back/e/4/e454bf31-5aa0-4109-a3f5-c3f9cc838682.jpg?1682715370"], "FlavorText": ["", "Against the implacable will of Phyrexia, the dryads of Moag raised a shield of living summer."], "FlavorName": ["", ""]}], "Keywords": ["Transform", "Ward"], "TypeLine": "Battle \u2014 Siege // Creature \u2014 Dryad", "Legalities": {"standard": "legal", "future": "legal", "historic": "legal", "timeless": "legal", "gladiator": "legal", "pioneer": "legal", "explorer": "legal", "modern": "legal", "legacy": "legal", "pauper": "not_legal", "vintage": "legal", "penny": "not_legal", "commander": "legal", "oathbreaker": "legal", "standardbrawl": "legal", "brawl": "legal", "alchemy": "legal", "paupercommander": "not_legal", "duel": "legal", "oldschool": "not_legal", "premodern": "not_legal", "predh": "not_legal"}},
#  {"Name": "Invasion of New Capenna // Holy Frazzle-Cannon", "Faces": [{"Name": "Invasion of New Capenna", "ManaCost": "{W}{B}", "TypeLine": "Battle \u2014 Siege", "OracleText": "(As a Siege enters, choose an opponent to protect it. You and others can attack it. When it's defeated, exile it, then cast it transformed.)\nWhen Invasion of New Capenna enters the battlefield, you may sacrifice an artifact or creature. When you do, exile target artifact or creature an opponent controls.", "Power": null, "Toughness": null, "Defense": "4"}, {"Name": "Holy Frazzle-Cannon", "ManaCost": "", "TypeLine": "Artifact \u2014 Equipment", "OracleText": "Whenever equipped creature attacks, put a +1/+1 counter on that creature and each other creature you control that shares a creature type with it.\nEquip {1}", "Power": null, "Toughness": null, "Defense": null}], "ColorIdentity": ["B", "W"], "CMC": 2.0, "Variants": [{"SetName": "March of the Machine", "SetCode": "mom", "CollNum": "238", "Finishes": ["nonfoil", "foil"], "Artist": "Diego Gisbert", "Language": "en", "Released": "2023-04-21", "Rarity": "uncommon", "Thumb": ["https://cards.scryfall.io/small/front/f/5/f5926c8e-8049-418e-9a84-f8558e5ba9d1.jpg?1682715382", "https://cards.scryfall.io/small/back/f/5/f5926c8e-8049-418e-9a84-f8558e5ba9d1.jpg?1682715382"], "Image": ["https://cards.scryfall.io/normal/front/f/5/f5926c8e-8049-418e-9a84-f8558e5ba9d1.jpg?1682715382", "https://cards.scryfall.io/normal/back/f/5/f5926c8e-8049-418e-9a84-f8558e5ba9d1.jpg?1682715382"], "FlavorText": ["", "\"They're using my Halo stockpile for what?\"\n\u2014Jetmir"], "FlavorName": ["", ""]}], "Keywords": ["Transform", "Equip"], "TypeLine": "Battle \u2014 Siege // Artifact \u2014 Equipment", "Legalities": {"standard": "legal", "future": "legal", "historic": "legal", "timeless": "legal", "gladiator": "legal", "pioneer": "legal", "explorer": "legal", "modern": "legal", "legacy": "legal", "pauper": "not_legal", "vintage": "legal", "penny": "not_legal", "commander": "legal", "oathbreaker": "legal", "standardbrawl": "legal", "brawl": "legal", "alchemy": "legal", "paupercommander": "not_legal", "duel": "legal", "oldschool": "not_legal", "premodern": "not_legal", "predh": "not_legal"}}]

# %%
[i for i in flagged if 'image_uris' not in i and i['card_faces'][0]['artist'] != i['card_faces'][1]['artist']][1]
# Out:
# {'object': 'card',
#  'id': '1f6213d9-c65d-48da-a501-279db5f31d6a',
#  'oracle_id': '0b55eac6-a745-4bf4-8926-5ce83bc38d7d',
#  'multiverse_ids': [],
#  'tcgplayer_id': 151718,
#  'cardmarket_id': 313036,
#  'name': 'Treasure Map // Treasure Cove',
#  'lang': 'en',
#  'released_at': '2017-11-24',
#  'uri': 'https://api.scryfall.com/cards/1f6213d9-c65d-48da-a501-279db5f31d6a',
#  'scryfall_uri': 'https://scryfall.com/card/pxtc/250/treasure-map-treasure-cove?utm_source=api',
#  'layout': 'transform',
#  'highres_image': True,
#  'image_status': 'highres_scan',
#  'cmc': 2.0,
#  'type_line': 'Artifact // Land',
#  'color_identity': [],
#  'keywords': ['Transform', 'Treasure', 'Scry'],
#  'produced_mana': ['B', 'C', 'G', 'R', 'U', 'W'],
#  'card_faces': [{'object': 'card_face',
#    'name': 'Treasure Map',
#    'mana_cost': '{2}',
#    'type_line': 'Artifact',
#    'oracle_text': '{1}, {T}: Scry 1. Put a landmark counter on Treasure Map. Then if there are three or more landmark counters on it, remove those counters, transform Treasure Map, and create three Treasure tokens. (They\'re artifacts with "{T}, Sacrifice this artifact: Add one mana of any color.")',
#    'colors': [],
#    'watermark': 'set',
#    'artist': 'Cliff Childs',
#    'artist_id': 'ed6f7e03-20ba-4c73-bdda-4a4928480721',
#    'illustration_id': 'f7970d54-58c3-40aa-ad1d-45e4536c9c73',
#    'image_uris': {'small': 'https://cards.scryfall.io/small/front/1/f/1f6213d9-c65d-48da-a501-279db5f31d6a.jpg?1562271919',
#     'normal': 'https://cards.scryfall.io/normal/front/1/f/1f6213d9-c65d-48da-a501-279db5f31d6a.jpg?1562271919',
#     'large': 'https://cards.scryfall.io/large/front/1/f/1f6213d9-c65d-48da-a501-279db5f31d6a.jpg?1562271919',
#     'png': 'https://cards.scryfall.io/png/front/1/f/1f6213d9-c65d-48da-a501-279db5f31d6a.png?1562271919',
#     'art_crop': 'https://cards.scryfall.io/art_crop/front/1/f/1f6213d9-c65d-48da-a501-279db5f31d6a.jpg?1562271919',
#     'border_crop': 'https://cards.scryfall.io/border_crop/front/1/f/1f6213d9-c65d-48da-a501-279db5f31d6a.jpg?1562271919'}},
#   {'object': 'card_face',
#    'name': 'Treasure Cove',
#    'flavor_name': '',
#    'mana_cost': '',
#    'type_line': 'Land',
#    'oracle_text': '(Transforms from Treasure Map.)\n{T}: Add {C}.\n{T}, Sacrifice a Treasure: Draw a card.',
#    'colors': [],
#    'flavor_text': 'Half the treasure is the glory of finding it.',
#    'artist': 'Jared Blando',
#    'artist_id': '61b8414b-31e8-4c43-893d-7efe72293d3c',
#    'illustration_id': 'f4242de5-45ee-401d-8e67-27e10492fb14',
#    'image_uris': {'small': 'https://cards.scryfall.io/small/back/1/f/1f6213d9-c65d-48da-a501-279db5f31d6a.jpg?1562271919',
#     'normal': 'https://cards.scryfall.io/normal/back/1/f/1f6213d9-c65d-48da-a501-279db5f31d6a.jpg?1562271919',
#     'large': 'https://cards.scryfall.io/large/back/1/f/1f6213d9-c65d-48da-a501-279db5f31d6a.jpg?1562271919',
#     'png': 'https://cards.scryfall.io/png/back/1/f/1f6213d9-c65d-48da-a501-279db5f31d6a.png?1562271919',
#     'art_crop': 'https://cards.scryfall.io/art_crop/back/1/f/1f6213d9-c65d-48da-a501-279db5f31d6a.jpg?1562271919',
#     'border_crop': 'https://cards.scryfall.io/border_crop/back/1/f/1f6213d9-c65d-48da-a501-279db5f31d6a.jpg?1562271919'}}],
#  'all_parts': [{'object': 'related_card',
#    'id': '1f6213d9-c65d-48da-a501-279db5f31d6a',
#    'component': 'combo_piece',
#    'name': 'Treasure Map // Treasure Cove',
#    'type_line': 'Artifact // Land',
#    'uri': 'https://api.scryfall.com/cards/1f6213d9-c65d-48da-a501-279db5f31d6a'},
#   {'object': 'related_card',
#    'id': 'bbe8bced-9524-47f6-a600-bf4ddc072698',
#    'component': 'token',
#    'name': 'Treasure',
#    'type_line': 'Token Artifact — Treasure',
#    'uri': 'https://api.scryfall.com/cards/bbe8bced-9524-47f6-a600-bf4ddc072698'},
#   {'object': 'related_card',
#    'id': '4a8b3030-5495-404b-938c-8c4a387a1341',
#    'component': 'combo_piece',
#    'name': 'Ixalan Checklist',
#    'type_line': 'Card',
#    'uri': 'https://api.scryfall.com/cards/4a8b3030-5495-404b-938c-8c4a387a1341'}],
#  'legalities': {'standard': 'legal',
#   'future': 'legal',
#   'historic': 'legal',
#   'timeless': 'legal',
#   'gladiator': 'legal',
#   'pioneer': 'legal',
#   'explorer': 'legal',
#   'modern': 'legal',
#   'legacy': 'legal',
#   'pauper': 'not_legal',
#   'vintage': 'legal',
#   'penny': 'legal',
#   'commander': 'legal',
#   'oathbreaker': 'legal',
#   'standardbrawl': 'legal',
#   'brawl': 'legal',
#   'alchemy': 'legal',
#   'paupercommander': 'not_legal',
#   'duel': 'legal',
#   'oldschool': 'not_legal',
#   'premodern': 'not_legal',
#   'predh': 'not_legal'},
#  'games': ['paper'],
#  'reserved': False,
#  'foil': True,
#  'nonfoil': False,
#  'finishes': ['foil'],
#  'oversized': False,
#  'promo': True,
#  'reprint': True,
#  'variation': False,
#  'set_id': '2b5230c7-25a8-4521-9f6a-7e3cefb07213',
#  'set': 'pxtc',
#  'set_name': 'XLN Treasure Chest',
#  'set_type': 'promo',
#  'set_uri': 'https://api.scryfall.com/sets/2b5230c7-25a8-4521-9f6a-7e3cefb07213',
#  'set_search_uri': 'https://api.scryfall.com/cards/search?order=set&q=e%3Apxtc&unique=prints',
#  'scryfall_set_uri': 'https://scryfall.com/sets/pxtc?utm_source=api',
#  'rulings_uri': 'https://api.scryfall.com/cards/1f6213d9-c65d-48da-a501-279db5f31d6a/rulings',
#  'prints_search_uri': 'https://api.scryfall.com/cards/search?order=released&q=oracleid%3A0b55eac6-a745-4bf4-8926-5ce83bc38d7d&unique=prints',
#  'collector_number': '250',
#  'digital': False,
#  'rarity': 'rare',
#  'artist': 'Cliff Childs & Jared Blando',
#  'artist_ids': ['ed6f7e03-20ba-4c73-bdda-4a4928480721',
#   '61b8414b-31e8-4c43-893d-7efe72293d3c'],
#  'border_color': 'black',
#  'frame': '2015',
#  'frame_effects': ['compasslanddfc'],
#  'security_stamp': 'oval',
#  'full_art': False,
#  'textless': False,
#  'booster': False,
#  'story_spotlight': False,
#  'promo_types': ['buyabox'],
#  'edhrec_rank': 1786,
#  'penny_rank': 1504,
#  'prices': {'usd': None,
#   'usd_foil': '6.17',
#   'usd_etched': None,
#   'eur': None,
#   'eur_foil': '4.51',
#   'tix': None},
#  'related_uris': {'tcgplayer_infinite_articles': 'https://tcgplayer.pxf.io/c/4931599/1830156/21018?subId1=api&trafcat=infinite&u=https%3A%2F%2Finfinite.tcgplayer.com%2Fsearch%3FcontentMode%3Darticle%26game%3Dmagic%26partner%3Dscryfall%26q%3DTreasure%2BMap%2B%252F%252F%2BTreasure%2BCove',
#   'tcgplayer_infinite_decks': 'https://tcgplayer.pxf.io/c/4931599/1830156/21018?subId1=api&trafcat=infinite&u=https%3A%2F%2Finfinite.tcgplayer.com%2Fsearch%3FcontentMode%3Ddeck%26game%3Dmagic%26partner%3Dscryfall%26q%3DTreasure%2BMap%2B%252F%252F%2BTreasure%2BCove',
#   'edhrec': 'https://edhrec.com/route/?cc=Treasure+Map'},
#  'purchase_uris': {'tcgplayer': 'https://tcgplayer.pxf.io/c/4931599/1830156/21018?subId1=api&u=https%3A%2F%2Fwww.tcgplayer.com%2Fproduct%2F151718%3Fpage%3D1',
#   'cardmarket': 'https://www.cardmarket.com/en/Magic/Products/Singles/Buy-a-Box-Promos/Treasure-Map-Treasure-Cove?referrer=scryfall&utm_campaign=card_prices&utm_medium=text&utm_source=scryfall',
#   'cardhoarder': 'https://www.cardhoarder.com/cards?affiliate_id=scryfall&data%5Bsearch%5D=Treasure+Map&ref=card-profile&utm_campaign=affiliate&utm_medium=card&utm_source=scryfall'}}

# %%
[i for i in flagged if 'card_faces' in i and 'flavor_name' in i['card_faces'][0]][0]
# Out:
# {'object': 'card',
#  'id': '0954ed3d-a5d8-4330-b07c-bf3e51192e4b',
#  'oracle_id': 'a720f3d3-c2d7-4e50-8cc6-600120380e9c',
#  'multiverse_ids': [544475, 544476],
#  'arena_id': 79141,
#  'tcgplayer_id': 253196,
#  'cardmarket_id': 581328,
#  'name': 'Voldaren Bloodcaster // Bloodbat Summoner',
#  'lang': 'en',
#  'released_at': '2021-11-19',
#  'uri': 'https://api.scryfall.com/cards/0954ed3d-a5d8-4330-b07c-bf3e51192e4b',
#  'scryfall_uri': 'https://scryfall.com/card/vow/338/voldaren-bloodcaster-bloodbat-summoner?utm_source=api',
#  'layout': 'transform',
#  'highres_image': True,
#  'image_status': 'highres_scan',
#  'cmc': 2.0,
#  'type_line': 'Creature — Vampire Wizard // Creature — Vampire Wizard',
#  'color_identity': ['B'],
#  'keywords': ['Flying', 'Transform'],
#  'card_faces': [{'object': 'card_face',
#    'name': 'Voldaren Bloodcaster',
#    'flavor_name': 'Dracula, Lord of Blood',
#    'mana_cost': '{1}{B}',
#    'type_line': 'Creature — Vampire Wizard',
#    'oracle_text': 'Flying\nWhenever Voldaren Bloodcaster or another nontoken creature you control dies, create a Blood token. (It\'s an artifact with "{1}, {T}, Discard a card, Sacrifice this artifact: Draw a card.")\nWhenever you create a Blood token, if you control five or more Blood tokens, transform Voldaren Bloodcaster.',
#    'colors': ['B'],
#    'power': '2',
#    'toughness': '1',
#    'artist': 'Johann Bodin',
#    'artist_id': 'd92e2dd9-9ef6-43f6-81f8-df87f9066983',
#    'illustration_id': '3d5d971e-abd6-4161-a203-bd20e36f89a8',
#    'image_uris': {'small': 'https://cards.scryfall.io/small/front/0/9/0954ed3d-a5d8-4330-b07c-bf3e51192e4b.jpg?1645227339',
#     'normal': 'https://cards.scryfall.io/normal/front/0/9/0954ed3d-a5d8-4330-b07c-bf3e51192e4b.jpg?1645227339',
#     'large': 'https://cards.scryfall.io/large/front/0/9/0954ed3d-a5d8-4330-b07c-bf3e51192e4b.jpg?1645227339',
#     'png': 'https://cards.scryfall.io/png/front/0/9/0954ed3d-a5d8-4330-b07c-bf3e51192e4b.png?1645227339',
#     'art_crop': 'https://cards.scryfall.io/art_crop/front/0/9/0954ed3d-a5d8-4330-b07c-bf3e51192e4b.jpg?1645227339',
#     'border_crop': 'https://cards.scryfall.io/border_crop/front/0/9/0954ed3d-a5d8-4330-b07c-bf3e51192e4b.jpg?1645227339'}},
#   {'object': 'card_face',
#    'name': 'Bloodbat Summoner',
#    'flavor_name': 'Dracula, Lord of Bats',
#    'mana_cost': '',
#    'type_line': 'Creature — Vampire Wizard',
#    'oracle_text': 'Flying\nAt the beginning of combat on your turn, up to one target Blood token you control becomes a 2/2 black Bat creature with flying and haste in addition to its other types.',
#    'colors': ['B'],
#    'color_indicator': ['B'],
#    'power': '3',
#    'toughness': '3',
#    'flavor_text': '"Do you mean to tell me that Lucy was bitten by such a bat . . . ?"',
#    'artist': 'Johann Bodin',
#    'artist_id': 'd92e2dd9-9ef6-43f6-81f8-df87f9066983',
#    'illustration_id': '9c190f1e-4004-4f01-b799-e866f1d9da2b',
#    'image_uris': {'small': 'https://cards.scryfall.io/small/back/0/9/0954ed3d-a5d8-4330-b07c-bf3e51192e4b.jpg?1645227339',
#     'normal': 'https://cards.scryfall.io/normal/back/0/9/0954ed3d-a5d8-4330-b07c-bf3e51192e4b.jpg?1645227339',
#     'large': 'https://cards.scryfall.io/large/back/0/9/0954ed3d-a5d8-4330-b07c-bf3e51192e4b.jpg?1645227339',
#     'png': 'https://cards.scryfall.io/png/back/0/9/0954ed3d-a5d8-4330-b07c-bf3e51192e4b.png?1645227339',
#     'art_crop': 'https://cards.scryfall.io/art_crop/back/0/9/0954ed3d-a5d8-4330-b07c-bf3e51192e4b.jpg?1645227339',
#     'border_crop': 'https://cards.scryfall.io/border_crop/back/0/9/0954ed3d-a5d8-4330-b07c-bf3e51192e4b.jpg?1645227339'}}],
#  'all_parts': [{'object': 'related_card',
#    'id': 'a6f374bc-cd29-469f-808a-6a6c004ee8aa',
#    'component': 'token',
#    'name': 'Blood',
#    'type_line': 'Token Artifact — Blood',
#    'uri': 'https://api.scryfall.com/cards/a6f374bc-cd29-469f-808a-6a6c004ee8aa'},
#   {'object': 'related_card',
#    'id': '0954ed3d-a5d8-4330-b07c-bf3e51192e4b',
#    'component': 'combo_piece',
#    'name': 'Voldaren Bloodcaster // Bloodbat Summoner',
#    'type_line': 'Creature — Vampire Wizard // Creature — Vampire Wizard',
#    'uri': 'https://api.scryfall.com/cards/0954ed3d-a5d8-4330-b07c-bf3e51192e4b'}],
#  'legalities': {'standard': 'legal',
#   'future': 'not_legal',
#   'historic': 'legal',
#   'timeless': 'legal',
#   'gladiator': 'legal',
#   'pioneer': 'legal',
#   'explorer': 'legal',
#   'modern': 'legal',
#   'legacy': 'legal',
#   'pauper': 'not_legal',
#   'vintage': 'legal',
#   'penny': 'legal',
#   'commander': 'legal',
#   'oathbreaker': 'legal',
#   'standardbrawl': 'legal',
#   'brawl': 'legal',
#   'alchemy': 'not_legal',
#   'paupercommander': 'not_legal',
#   'duel': 'legal',
#   'oldschool': 'not_legal',
#   'premodern': 'not_legal',
#   'predh': 'not_legal'},
#  'games': ['arena', 'paper', 'mtgo'],
#  'reserved': False,
#  'foil': True,
#  'nonfoil': True,
#  'finishes': ['nonfoil', 'foil'],
#  'oversized': False,
#  'promo': False,
#  'reprint': False,
#  'variation': False,
#  'set_id': '8144b676-569f-4716-8005-bc8f0778f3fa',
#  'set': 'vow',
#  'set_name': 'Innistrad: Crimson Vow',
#  'set_type': 'expansion',
#  'set_uri': 'https://api.scryfall.com/sets/8144b676-569f-4716-8005-bc8f0778f3fa',
#  'set_search_uri': 'https://api.scryfall.com/cards/search?order=set&q=e%3Avow&unique=prints',
#  'scryfall_set_uri': 'https://scryfall.com/sets/vow?utm_source=api',
#  'rulings_uri': 'https://api.scryfall.com/cards/0954ed3d-a5d8-4330-b07c-bf3e51192e4b/rulings',
#  'prints_search_uri': 'https://api.scryfall.com/cards/search?order=released&q=oracleid%3Aa720f3d3-c2d7-4e50-8cc6-600120380e9c&unique=prints',
#  'collector_number': '338',
#  'digital': False,
#  'rarity': 'rare',
#  'artist': 'Johann Bodin',
#  'artist_ids': ['d92e2dd9-9ef6-43f6-81f8-df87f9066983'],
#  'border_color': 'borderless',
#  'frame': '2015',
#  'frame_effects': ['sunmoondfc'],
#  'security_stamp': 'oval',
#  'full_art': True,
#  'textless': False,
#  'booster': False,
#  'story_spotlight': False,
#  'promo_types': ['draculaseries', 'boosterfun'],
#  'edhrec_rank': 5266,
#  'penny_rank': 5732,
#  'prices': {'usd': '2.09',
#   'usd_foil': '2.05',
#   'usd_etched': None,
#   'eur': '1.28',
#   'eur_foil': '2.10',
#   'tix': None},
#  'related_uris': {'gatherer': 'https://gatherer.wizards.com/Pages/Card/Details.aspx?multiverseid=544475&printed=false',
#   'tcgplayer_infinite_articles': 'https://tcgplayer.pxf.io/c/4931599/1830156/21018?subId1=api&trafcat=infinite&u=https%3A%2F%2Finfinite.tcgplayer.com%2Fsearch%3FcontentMode%3Darticle%26game%3Dmagic%26partner%3Dscryfall%26q%3DVoldaren%2BBloodcaster%2B%252F%252F%2BBloodbat%2BSummoner',
#   'tcgplayer_infinite_decks': 'https://tcgplayer.pxf.io/c/4931599/1830156/21018?subId1=api&trafcat=infinite&u=https%3A%2F%2Finfinite.tcgplayer.com%2Fsearch%3FcontentMode%3Ddeck%26game%3Dmagic%26partner%3Dscryfall%26q%3DVoldaren%2BBloodcaster%2B%252F%252F%2BBloodbat%2BSummoner',
#   'edhrec': 'https://edhrec.com/route/?cc=Voldaren+Bloodcaster'},
#  'purchase_uris': {'tcgplayer': 'https://tcgplayer.pxf.io/c/4931599/1830156/21018?subId1=api&u=https%3A%2F%2Fwww.tcgplayer.com%2Fproduct%2F253196%3Fpage%3D1',
#   'cardmarket': 'https://www.cardmarket.com/en/Magic/Products/Singles/Innistrad-Crimson-Vow-Extras/Voldaren-Bloodcaster-Bloodbat-Summoner-V2?referrer=scryfall&utm_campaign=card_prices&utm_medium=text&utm_source=scryfall',
#   'cardhoarder': 'https://www.cardhoarder.com/cards?affiliate_id=scryfall&data%5Bsearch%5D=Voldaren+Bloodcaster&ref=card-profile&utm_campaign=affiliate&utm_medium=card&utm_source=scryfall'}}

# %%
[i['name'] for i in flagged if 'type_line' not in i]
# Out:
# ['Ghalta, Primal Hunger // Ghalta, Primal Hunger',
#  'Stitch in Time // Stitch in Time',
#  'Anointed Procession // Anointed Procession',
#  'Jetmir, Nexus of Revels // Jetmir, Nexus of Revels',
#  'Jace Beleren // Jace Beleren',
#  'Norin the Wary // Norin the Wary',
#  'Propaganda // Propaganda',
#  'Jace Beleren // Jace Beleren',
#  'Blightsteel Colossus // Blightsteel Colossus',
#  'Chandra Nalaar // Chandra Nalaar',
#  'Terror // Terror',
#  'Plains // Plains',
#  'Krark, the Thumbless // Krark, the Thumbless',
#  'Adrix and Nev, Twincasters // Adrix and Nev, Twincasters',
#  'Unholy Grotto // Unholy Grotto',
#  'Island // Island',
#  'Forest // Forest',
#  'Ulamog, the Ceaseless Hunger // Ulamog, the Ceaseless Hunger',
#  'Swamp // Swamp',
#  'Chandra Nalaar // Chandra Nalaar',
#  'Darksteel Colossus // Darksteel Colossus',
#  'Zombie Master // Zombie Master',
#  'Doubling Cube // Doubling Cube',
#  'Liliana Vess // Liliana Vess',
#  'Okaun, Eye of Chaos // Okaun, Eye of Chaos',
#  'Ajani Goldmane // Ajani Goldmane',
#  'Noxious Ghoul // Noxious Ghoul',
#  "Krark's Thumb // Krark's Thumb",
#  'Rin and Seri, Inseparable // Rin and Seri, Inseparable',
#  'Mountain // Mountain',
#  'Ajani Goldmane // Ajani Goldmane',
#  'Etali, Primal Storm // Etali, Primal Storm',
#  'Command Tower // Command Tower',
#  'Garruk Wildspeaker // Garruk Wildspeaker',
#  "Jinnie Fay, Jetmir's Second // Jinnie Fay, Jetmir's Second",
#  'Garruk Wildspeaker // Garruk Wildspeaker',
#  'Yargle, Glutton of Urborg // Yargle, Glutton of Urborg',
#  'Zndrsplt, Eye of Wisdom // Zndrsplt, Eye of Wisdom',
#  'Liliana Vess // Liliana Vess',
#  'Sol Ring // Sol Ring',
#  'Death Baron // Death Baron',
#  'Sakashima of a Thousand Faces // Sakashima of a Thousand Faces',
#  'Grimgrin, Corpse-Born // Grimgrin, Corpse-Born']

# %%
[i for i in flagged if 'card_faces' in i][1]
# Out:
# {'object': 'card',
#  'id': '00255899-aaaf-46c6-8037-bd0e3c06250c',
#  'oracle_id': '7f8dad7f-a573-469f-9095-4ba3886b4f0b',
#  'multiverse_ids': [607310, 607311],
#  'mtgo_id': 110392,
#  'arena_id': 84546,
#  'tcgplayer_id': 490498,
#  'cardmarket_id': 703462,
#  'name': 'Invasion of Tolvada // The Broken Sky',
#  'lang': 'en',
#  'released_at': '2023-04-21',
#  'uri': 'https://api.scryfall.com/cards/00255899-aaaf-46c6-8037-bd0e3c06250c',
#  'scryfall_uri': 'https://scryfall.com/card/mom/241/invasion-of-tolvada-the-broken-sky?utm_source=api',
#  'layout': 'transform',
#  'highres_image': True,
#  'image_status': 'highres_scan',
#  'cmc': 5.0,
#  'type_line': 'Battle — Siege // Enchantment',
#  'color_identity': ['B', 'W'],
#  'keywords': ['Transform'],
#  'card_faces': [{'object': 'card_face',
#    'name': 'Invasion of Tolvada',
#    'mana_cost': '{3}{W}{B}',
#    'type_line': 'Battle — Siege',
#    'oracle_text': "(As a Siege enters, choose an opponent to protect it. You and others can attack it. When it's defeated, exile it, then cast it transformed.)\nWhen Invasion of Tolvada enters the battlefield, return target nonbattle permanent card from your graveyard to the battlefield.",
#    'colors': ['B', 'W'],
#    'defense': '5',
#    'artist': 'Henry Peters',
#    'artist_id': '2ffd9e06-94af-44f5-bec6-06f781941a6c',
#    'illustration_id': 'e505aa78-b014-44aa-bee3-cb4f7dc587f0',
#    'image_uris': {'small': 'https://cards.scryfall.io/small/front/0/0/00255899-aaaf-46c6-8037-bd0e3c06250c.jpg?1682715701',
#     'normal': 'https://cards.scryfall.io/normal/front/0/0/00255899-aaaf-46c6-8037-bd0e3c06250c.jpg?1682715701',
#     'large': 'https://cards.scryfall.io/large/front/0/0/00255899-aaaf-46c6-8037-bd0e3c06250c.jpg?1682715701',
#     'png': 'https://cards.scryfall.io/png/front/0/0/00255899-aaaf-46c6-8037-bd0e3c06250c.png?1682715701',
#     'art_crop': 'https://cards.scryfall.io/art_crop/front/0/0/00255899-aaaf-46c6-8037-bd0e3c06250c.jpg?1682715701',
#     'border_crop': 'https://cards.scryfall.io/border_crop/front/0/0/00255899-aaaf-46c6-8037-bd0e3c06250c.jpg?1682715701'}},
#   {'object': 'card_face',
#    'name': 'The Broken Sky',
#    'flavor_name': '',
#    'mana_cost': '',
#    'type_line': 'Enchantment',
#    'oracle_text': 'Creature tokens you control get +1/+0 and have lifelink.\nAt the beginning of your end step, create a 1/1 white and black Spirit creature token with flying.',
#    'colors': ['B', 'W'],
#    'color_indicator': ['B', 'W'],
#    'flavor_text': 'Angry ghosts poured through and pummeled the Invasion Tree, filling the heavens with the rhythms of war.',
#    'artist': 'Henry Peters',
#    'artist_id': '2ffd9e06-94af-44f5-bec6-06f781941a6c',
#    'illustration_id': 'e61d567e-03dc-4c8a-a773-65ae8cd7fdc9',
#    'image_uris': {'small': 'https://cards.scryfall.io/small/back/0/0/00255899-aaaf-46c6-8037-bd0e3c06250c.jpg?1682715701',
#     'normal': 'https://cards.scryfall.io/normal/back/0/0/00255899-aaaf-46c6-8037-bd0e3c06250c.jpg?1682715701',
#     'large': 'https://cards.scryfall.io/large/back/0/0/00255899-aaaf-46c6-8037-bd0e3c06250c.jpg?1682715701',
#     'png': 'https://cards.scryfall.io/png/back/0/0/00255899-aaaf-46c6-8037-bd0e3c06250c.png?1682715701',
#     'art_crop': 'https://cards.scryfall.io/art_crop/back/0/0/00255899-aaaf-46c6-8037-bd0e3c06250c.jpg?1682715701',
#     'border_crop': 'https://cards.scryfall.io/border_crop/back/0/0/00255899-aaaf-46c6-8037-bd0e3c06250c.jpg?1682715701'}}],
#  'all_parts': [{'object': 'related_card',
#    'id': '6d02a57e-6c76-491c-85f8-8f4d825be2c2',
#    'component': 'token',
#    'name': 'Spirit',
#    'type_line': 'Token Creature — Spirit',
#    'uri': 'https://api.scryfall.com/cards/6d02a57e-6c76-491c-85f8-8f4d825be2c2'},
#   {'object': 'related_card',
#    'id': '00255899-aaaf-46c6-8037-bd0e3c06250c',
#    'component': 'combo_piece',
#    'name': 'Invasion of Tolvada // The Broken Sky',
#    'type_line': 'Battle — Siege // Enchantment',
#    'uri': 'https://api.scryfall.com/cards/00255899-aaaf-46c6-8037-bd0e3c06250c'}],
#  'legalities': {'standard': 'legal',
#   'future': 'legal',
#   'historic': 'legal',
#   'timeless': 'legal',
#   'gladiator': 'legal',
#   'pioneer': 'legal',
#   'explorer': 'legal',
#   'modern': 'legal',
#   'legacy': 'legal',
#   'pauper': 'not_legal',
#   'vintage': 'legal',
#   'penny': 'legal',
#   'commander': 'legal',
#   'oathbreaker': 'legal',
#   'standardbrawl': 'legal',
#   'brawl': 'legal',
#   'alchemy': 'legal',
#   'paupercommander': 'not_legal',
#   'duel': 'legal',
#   'oldschool': 'not_legal',
#   'premodern': 'not_legal',
#   'predh': 'not_legal'},
#  'games': ['paper', 'mtgo', 'arena'],
#  'reserved': False,
#  'foil': True,
#  'nonfoil': True,
#  'finishes': ['nonfoil', 'foil'],
#  'oversized': False,
#  'promo': False,
#  'reprint': False,
#  'variation': False,
#  'set_id': '392f7315-dc53-40a3-a2cc-5482dbd498b3',
#  'set': 'mom',
#  'set_name': 'March of the Machine',
#  'set_type': 'expansion',
#  'set_uri': 'https://api.scryfall.com/sets/392f7315-dc53-40a3-a2cc-5482dbd498b3',
#  'set_search_uri': 'https://api.scryfall.com/cards/search?order=set&q=e%3Amom&unique=prints',
#  'scryfall_set_uri': 'https://scryfall.com/sets/mom?utm_source=api',
#  'rulings_uri': 'https://api.scryfall.com/cards/00255899-aaaf-46c6-8037-bd0e3c06250c/rulings',
#  'prints_search_uri': 'https://api.scryfall.com/cards/search?order=released&q=oracleid%3A7f8dad7f-a573-469f-9095-4ba3886b4f0b&unique=prints',
#  'collector_number': '241',
#  'digital': False,
#  'rarity': 'rare',
#  'artist': 'Henry Peters',
#  'artist_ids': ['2ffd9e06-94af-44f5-bec6-06f781941a6c'],
#  'border_color': 'black',
#  'frame': '2015',
#  'security_stamp': 'oval',
#  'full_art': False,
#  'textless': False,
#  'booster': True,
#  'story_spotlight': False,
#  'edhrec_rank': 6987,
#  'penny_rank': 4989,
#  'preview': {'source': 'Sean Plott (Day9TV)',
#   'source_uri': 'https://twitter.com/day9tv/status/1641107950612934656',
#   'previewed_at': '2023-03-29'},
#  'prices': {'usd': '0.27',
#   'usd_foil': '0.83',
#   'usd_etched': None,
#   'eur': '0.29',
#   'eur_foil': '0.38',
#   'tix': '0.02'},
#  'related_uris': {'gatherer': 'https://gatherer.wizards.com/Pages/Card/Details.aspx?multiverseid=607310&printed=false',
#   'tcgplayer_infinite_articles': 'https://tcgplayer.pxf.io/c/4931599/1830156/21018?subId1=api&trafcat=infinite&u=https%3A%2F%2Finfinite.tcgplayer.com%2Fsearch%3FcontentMode%3Darticle%26game%3Dmagic%26partner%3Dscryfall%26q%3DInvasion%2Bof%2BTolvada%2B%252F%252F%2BThe%2BBroken%2BSky',
#   'tcgplayer_infinite_decks': 'https://tcgplayer.pxf.io/c/4931599/1830156/21018?subId1=api&trafcat=infinite&u=https%3A%2F%2Finfinite.tcgplayer.com%2Fsearch%3FcontentMode%3Ddeck%26game%3Dmagic%26partner%3Dscryfall%26q%3DInvasion%2Bof%2BTolvada%2B%252F%252F%2BThe%2BBroken%2BSky',
#   'edhrec': 'https://edhrec.com/route/?cc=Invasion+of+Tolvada'},
#  'purchase_uris': {'tcgplayer': 'https://tcgplayer.pxf.io/c/4931599/1830156/21018?subId1=api&u=https%3A%2F%2Fwww.tcgplayer.com%2Fproduct%2F490498%3Fpage%3D1',
#   'cardmarket': 'https://www.cardmarket.com/en/Magic/Products/Singles/March-of-the-Machine/Invasion-of-Tolvada-The-Broken-Sky?referrer=scryfall&utm_campaign=card_prices&utm_medium=text&utm_source=scryfall',
#   'cardhoarder': 'https://www.cardhoarder.com/cards/110392?affiliate_id=scryfall&ref=card-profile&utm_campaign=affiliate&utm_medium=card&utm_source=scryfall'}}

# %%
def Parser(jsonEntries):
    database = {}
    skipped = {
        'missingID' : 0,
        'digitalOnly' : 0,
        'badLayout' : 0,
        'badPromotype' : 0,
        'missingIMG' : 0,
        'other' : 0
    }
    for jsonEntry in jsonEntries:
#         if 'oracle_id' not in jsonEntry:
#             skipped['missingID'] += 1
#             continue
        if 'paper' not in jsonEntry['games']:
            skipped['digitalOnly'] += 1
            continue
        if jsonEntry['layout'] in ['art_series', 'double_faced_token', 'token', 'planar', 'scheme', 'host', 'vanguard', 'emblem']:
            skipped['badLayout'] += 1
            continue
        if 'promo_types' in jsonEntry:
            if 'thick' in jsonEntry['promo_types']:
                skipped['badPromotype'] += 1
                continue
        if 'image_uris' not in jsonEntry: # transform, modal_dfc, reversible_card
            1 # store face as main object, store back in FlipSide att., how to adopt Variants att.?
        try:
            if 'oracle_id' not in jsonEntry: # these are cards with flip arts so id[0] == id[1]
                jsonEntry['oracle_id'] = jsonEntry['card_faces'][0]['oracle_id']
            for i in ['flavor_name', 'flavor_text']:
                if i not in jsonEntry:
                    jsonEntry[i] = ""
            if jsonEntry['oracle_id'] not in database:
                database[jsonEntry['oracle_id']] = {
                    'OracleId' : jsonEntry['oracle_id'],
                    'Name' : jsonEntry['name'],
                    'Variants' : [],
                    'TypeLine' : jsonEntry['type_line'],
                    'OracleText' : jsonEntry['oracle_text'],
                    'ManaCost' : jsonEntry['mana_cost'],
                    'CMC' : jsonEntry['cmc'],
                    'Colors' : jsonEntry['colors'],
                    'ColorIdentity' : jsonEntry['color_identity'],
                    'Keywords' : jsonEntry['keywords'],
                    'Legalities' : jsonEntry['legalities']
                }
            database[jsonEntry['oracle_id']]['Variants'] += [{
                'SetName' : jsonEntry['set_name'],
                'SetCode' : jsonEntry['set'],
                'CollNum' : jsonEntry['collector_number'],
                'Finishes' : jsonEntry['finishes'],
                'Artist' : jsonEntry['artist'],
                'Thumb' : jsonEntry['image_uris']['small'],
                'Image' : jsonEntry['image_uris']['normal'],
                'Language' : jsonEntry['lang'],
                'Released' : jsonEntry['released_at'],
                'Rarity' : jsonEntry['rarity'],
                'FlavorName' : jsonEntry['flavor_name'],
                'FlavorText' : jsonEntry['flavor_text']
            }]
        except:
            skipped['other'] += 1
            pass
    return skipped, database

skipped, database = Parser(wop)
        
print('Skipped', skipped, 'entries')
print(len(database), 'entries')

keys = database.keys()
dbsize = 0
for key in keys:
    dbsize += len(json.dumps(database[key]))
    
print('{:.2f} mb'.format(dbsize / 1000 / 1000))
# Out:
# Skipped {'missingID': 0, 'digitalOnly': 8359, 'badLayout': 4867, 'badPromotype': 89, 'missingIMG': 0, 'other': 1583} entries
# 28019 entries
# 66.02 mb

# %%
sum(['image_uris' not in i and 'card_faces' not in i for i in wop])
# Out:
# 0

# %%
sum(['card_faces' in i for i in wop])
# Out:
# 3735

# %%
set([i['layout'] for i in wop if 'image_uris' not in i and 'card_faces' in i])
# Out:
# {'art_series',
#  'double_faced_token',
#  'modal_dfc',
#  'reversible_card',
#  'transform'}

# %%
[oracleDatabase[i] for i in oracleDatabase if 'Wojek Investigator' in oracleDatabase[i]['Name']]
# Out:
# [{'OracleId': 'ab41243d-b178-4ebe-a7ac-bea37427be99',
#   'Name': 'Wojek Investigator',
#   'Variants': [],
#   'TypeLine': 'Creature — Angel Detective',
#   'OracleText': 'Flying, vigilance\nAt the beginning of your upkeep, investigate once for each opponent who has more cards in hand than you. (To investigate, create a Clue token. It\'s an artifact with "{2}, Sacrifice this artifact: Draw a card.")',
#   'ManaCost': '{2}{W}',
#   'CMC': 3.0,
#   'Colors': ['W'],
#   'ColorIdentity': ['W'],
#   'Keywords': ['Flying', 'Investigate', 'Vigilance'],
#   'Legalities': {'standard': 'legal',
#    'future': 'legal',
#    'historic': 'legal',
#    'timeless': 'legal',
#    'gladiator': 'legal',
#    'pioneer': 'legal',
#    'explorer': 'legal',
#    'modern': 'legal',
#    'legacy': 'legal',
#    'pauper': 'not_legal',
#    'vintage': 'legal',
#    'penny': 'legal',
#    'commander': 'legal',
#    'oathbreaker': 'legal',
#    'standardbrawl': 'legal',
#    'brawl': 'legal',
#    'alchemy': 'legal',
#    'paupercommander': 'not_legal',
#    'duel': 'legal',
#    'oldschool': 'not_legal',
#    'premodern': 'not_legal',
#    'predh': 'not_legal'}}]

# %%
scryfallUri = "https://api.scryfall.com/"

def Search(searchValue):
    searchUri = ""
    for char in searchValue.lower():
        if char in "abcdefghijklmnopqrstuvwxyz0123456789 ":
            searchUri += char
    searchUri = searchUri.replace(' ', '+')
    resp = requests.get(scryfallUri + "cards/named?fuzzy=" + searchUri)
    return json.loads(resp.text)

def Variants(cardObject):
    oracleId = cardObject['oracle_id']
    resp = requests.get(scryfallUri + "cards/search?order=released&unique=prints&q=game%3Apaper+oracleid%3A" + oracleId)
    vdat = json.loads(resp.text)['data']
    vlst = []
    for i in vdat:
        cdat = {
            'finishes' : i['finishes'],
            'scryfall' : i['id'],
            'thumb' : i['image_uris']['small'],
            'image' : i['image_uris']['normal']
        }
        vlst += [["{} ({}) {}".format(i['set_name'], i['set'], i['collector_number']), cdat]]
    return vlst

# %%
wok = Variants(Search('wojek invest'))
wok
# Out:
# [['Murders at Karlov Manor Promos (pmkm) 36s',
#   {'finishes': ['foil'],
#    'scryfall': '97b2df60-f773-4b61-9101-05642a227cf5',
#    'thumb': 'https://cards.scryfall.io/small/front/9/7/97b2df60-f773-4b61-9101-05642a227cf5.jpg?1707551491',
#    'image': 'https://cards.scryfall.io/normal/front/9/7/97b2df60-f773-4b61-9101-05642a227cf5.jpg?1707551491'}],
#  ['Murders at Karlov Manor Promos (pmkm) 36p',
#   {'finishes': ['nonfoil', 'foil'],
#    'scryfall': '091748a0-6a01-40cb-9ab8-015aa8235d3c',
#    'thumb': 'https://cards.scryfall.io/small/front/0/9/091748a0-6a01-40cb-9ab8-015aa8235d3c.jpg?1707510568',
#    'image': 'https://cards.scryfall.io/normal/front/0/9/091748a0-6a01-40cb-9ab8-015aa8235d3c.jpg?1707510568'}],
#  ['Murders at Karlov Manor (mkm) 429',
#   {'finishes': ['foil'],
#    'scryfall': '58eccc85-bdfe-48f4-a79e-76d9ef122815',
#    'thumb': 'https://cards.scryfall.io/small/front/5/8/58eccc85-bdfe-48f4-a79e-76d9ef122815.jpg?1712996935',
#    'image': 'https://cards.scryfall.io/normal/front/5/8/58eccc85-bdfe-48f4-a79e-76d9ef122815.jpg?1712996935'}],
#  ['Murders at Karlov Manor (mkm) 340',
#   {'finishes': ['nonfoil', 'foil'],
#    'scryfall': '481b5d9a-872d-4a2f-a52a-d4a746ee04ab',
#    'thumb': 'https://cards.scryfall.io/small/front/4/8/481b5d9a-872d-4a2f-a52a-d4a746ee04ab.jpg?1706242574',
#    'image': 'https://cards.scryfall.io/normal/front/4/8/481b5d9a-872d-4a2f-a52a-d4a746ee04ab.jpg?1706242574'}],
#  ['Murders at Karlov Manor (mkm) 36',
#   {'finishes': ['nonfoil', 'foil'],
#    'scryfall': '296574c6-3933-4ab3-b591-72514b244da9',
#    'thumb': 'https://cards.scryfall.io/small/front/2/9/296574c6-3933-4ab3-b591-72514b244da9.jpg?1706241546',
#    'image': 'https://cards.scryfall.io/normal/front/2/9/296574c6-3933-4ab3-b591-72514b244da9.jpg?1706241546'}]]

# %%
[Image.open(io.BytesIO(requests.get(i[1]['thumb']).content)) for i in wok]
# Out:
# [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=146x204>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=146x204>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=146x204>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=146x204>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=146x204>]

# %%
offlineKeys = {
    'object' : True,
    'id': True,
    'oracle_id' : True,
    'multiverse_ids' : False,
    'mtgo_id' : False,
    'mtgo_foil_id' : False,
    'tcgplayer_id' : False,
    'cardmarket_id' : False,
    'name' : True,
    'lang' : True,
    'released_at' : True,
    'uri' : False,
    'scryfall_uri' : False,
    'layout' : True,
    'highres_image' : False,
    'image_status' : False,
    'image_uris' : False,
    'mana_cost' : True,
    'cmc' : True,
    'type_line' : True,
    'oracle_text' : True,
    'power' : True,
    'toughness' : True,
    'colors' : True,
    'color_identity' : True,
    'keywords' : True,
    'all_parts' : False,
    'legalities' : True,
    'games' : False,
    'reserved' : False,
    'foil' : False,
    'nonfoil' : False,
    'finishes' : False,
    'oversized' : False,
    'promo' : False,
    'reprint' : False,
    'variation' : False,
    'set_id' : False,
    'set_name' : True,
    'set_type' : False,
    'set_uri' : False,
    'set_search_uri' : False,
    'scryfall_set_uri' : False,
    'rulings_uri' : False,
    'prints_search_uri' : False,
    'collector_number' : True,
    'digital' : False,
    'rarity' : True,
    'card_back_id' : False,
    'artist' : True,
    'artist_ids' : False,
    'illustration_id' : False,
    'border_color' : False,
    'frame' : False,
    'security_stamp' : False,
    'full_art' : False,
    'textless' : False,
    'booster' : False,
    'story_spotlight' : False,
    'edhrec_rank' : False,
    'penny_rank' : False,
    'prices' : False,
    'related_uris' : False,
    'purchase_uris' : False
}

# %%
fullJSON = json.loads(resp.content)

selectKeys = [i for i in offlineKeys if offlineKeys[i]]
offlineJSON = { i : fullJSON[i] for i in selectKeys}

# %%
offlineJSON
# Out:
# {'object': 'card',
#  'id': '6af12a34-52a1-4940-a8d5-9e9811fcd59f',
#  'oracle_id': 'e245d5c9-ae3a-4246-bd74-c6fed76b9fad',
#  'name': 'Temmet, Vizier of Naktamun',
#  'lang': 'en',
#  'released_at': '2017-04-28',
#  'layout': 'normal',
#  'mana_cost': '{W}{U}',
#  'cmc': 2.0,
#  'type_line': 'Legendary Creature — Human Cleric',
#  'oracle_text': "At the beginning of combat on your turn, target creature token you control gets +1/+1 until end of turn and can't be blocked this turn.\nEmbalm {3}{W}{U} ({3}{W}{U}, Exile this card from your graveyard: Create a token that's a copy of it, except it's a white Zombie Human Cleric with no mana cost. Embalm only as a sorcery.)",
#  'power': '2',
#  'toughness': '2',
#  'colors': ['U', 'W'],
#  'color_identity': ['U', 'W'],
#  'keywords': ['Embalm'],
#  'legalities': {'standard': 'not_legal',
#   'future': 'not_legal',
#   'historic': 'legal',
#   'timeless': 'legal',
#   'gladiator': 'legal',
#   'pioneer': 'legal',
#   'explorer': 'legal',
#   'modern': 'legal',
#   'legacy': 'legal',
#   'pauper': 'not_legal',
#   'vintage': 'legal',
#   'penny': 'legal',
#   'commander': 'legal',
#   'oathbreaker': 'legal',
#   'standardbrawl': 'not_legal',
#   'brawl': 'legal',
#   'alchemy': 'not_legal',
#   'paupercommander': 'not_legal',
#   'duel': 'legal',
#   'oldschool': 'not_legal',
#   'premodern': 'not_legal',
#   'predh': 'not_legal'},
#  'set_name': 'Amonkhet',
#  'collector_number': '207',
#  'rarity': 'rare',
#  'artist': 'Anna Steinbauer'}

# %%
len(resp.content), len(json.dumps(offlineJSON))
# Out:
# (5151, 1366)

# %%
numberCardsEDH = 15103

print('Full JSON size: {:5.1f} mb'.format(numberCardsEDH * len(resp.content) / 1000 / 1000))
print('Offl JSON size: {:5.1f} mb'.format(numberCardsEDH * len(json.dumps(offlineJSON)) / 1000 / 1000))
print('Imgs JSON size: {:5.1f} mb'.format(numberCardsEDH * len(requests.get(json.loads(resp.text)['image_uris']['small']).content) / 1000 / 1000))
# Out:
# Full JSON size:  77.8 mb
# Offl JSON size:  20.6 mb
# Imgs JSON size: 221.6 mb
